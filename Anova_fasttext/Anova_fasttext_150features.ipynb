# %% [markdown]
# Anova_fasttext_150 features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np 
import pandas as pd
from sklearn import preprocessing 
from sklearn.impute import SimpleImputer 
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_Fastext/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_Fastext/fasttext_150_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -0.458153 -0.604330 -0.517514 -0.660427 -0.354296 -0.289736
# 1           1 -1.051683  0.898375  0.698736  0.804972 -0.456383 -0.736347
# 2           2 -0.961684 -0.800367 -1.269184 -0.625000  0.484120  1.080715
# 3           3 -1.356337 -0.016740 -1.634334 -1.224549 -0.392996  0.515250
# 4           4 -1.159892 -1.098145 -1.387954 -0.779983  0.051495  0.145682
#
#           6         7         8  ...       140       141       142       143  \
# 0 -0.245397 -0.033325 -0.048851  ... -0.030138  0.429906  0.326622 -1.006781
# 1 -1.268381 -0.401375  1.214827  ... -0.627167 -0.744298  1.156346 -0.263460
# 2 -0.517575 -0.253032 -0.497499  ...  0.880275  0.592304  0.657381 -0.362565
# 3 -1.600238  0.002626 -0.634727  ...  1.204262 -0.604422  0.827262  0.051376
# 4 -0.666011  0.299061 -0.956696  ...  0.465914  0.741792  0.474371 -1.276400
#
#         144       145       146       147       148       149
# 0 -0.383814 -0.391396  0.340074  0.990894 -0.668944  0.685722
# 1 -0.469440  0.484755 -1.022867  1.020761 -0.768818 -0.472164
# 2  0.090224 -0.668494  0.185941  0.409489 -0.560275  0.914095
# 3 -1.363892 -0.814267 -0.672340  0.826573 -1.213216 -0.857825
# 4 -0.199087 -0.678408  0.279673  0.870620 -1.291742  1.422976
#
# [5 rows x 151 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.458153 -0.604330 -0.517514 -0.660427 -0.354296 -0.289736 -0.245397
# 1 -1.051683  0.898375  0.698736  0.804972 -0.456383 -0.736347 -1.268381
# 2 -0.961684 -0.800367 -1.269184 -0.625000  0.484120  1.080715 -0.517575
# 3 -1.356337 -0.016740 -1.634334 -1.224549 -0.392996  0.515250 -1.600238
# 4 -1.159892 -1.098145 -1.387954 -0.779983  0.051495  0.145682 -0.666011
#
#           7         8         9  ...       140       141       142       143  \
# 0 -0.033325 -0.048851 -0.367323  ... -0.030138  0.429906  0.326622 -1.006781
# 1 -0.401375  1.214827  0.175736  ... -0.627167 -0.744298  1.156346 -0.263460
# 2 -0.253032 -0.497499 -0.413774  ...  0.880275  0.592304  0.657381 -0.362565
# 3  0.002626 -0.634727 -0.888910  ...  1.204262 -0.604422  0.827262  0.051376
# 4  0.299061 -0.956696 -1.463262  ...  0.465914  0.741792  0.474371 -1.276400
#
#         144       145       146       147       148       149
# 0 -0.383814 -0.391396  0.340074  0.990894 -0.668944  0.685722
# 1 -0.469440  0.484755 -1.022867  1.020761 -0.768818 -0.472164
# 2  0.090224 -0.668494  0.185941  0.409489 -0.560275  0.914095
# 3 -1.363892 -0.814267 -0.672340  0.826573 -1.213216 -0.857825
# 4 -0.199087 -0.678408  0.279673  0.870620 -1.291742  1.422976
#
# [5 rows x 150 columns]

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 150), (524, 150))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.40127676370863136

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-20-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.545082      0.545082         0.590136
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.526927       0.349237     0.349237        0.330972       0.326065

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9972    0.9972    0.9972       361
#            2     0.9982    0.9982    0.9982       553
#            3     1.0000    1.0000    1.0000       306
#
#     accuracy                         0.9984      1220
#    macro avg     0.9985    0.9985    0.9985      1220
# weighted avg     0.9984    0.9984    0.9984      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3143    0.1401    0.1938       157
#            2     0.4455    0.7764    0.5662       237
#            3     0.2195    0.0692    0.1053       130
#
#     accuracy                         0.4103       524
#    macro avg     0.3264    0.3286    0.2884       524
# weighted avg     0.3501    0.4103    0.3403       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-20-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.545082      0.545082         0.590136
# 1   RandomForest        0.998361      0.998361         0.998361
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.526927       0.349237     0.349237        0.330972       0.326065
# 1        0.998361       0.410305     0.410305        0.350129       0.340256

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6276    0.4155    0.5000       361
#            2     0.5413    0.7939    0.6437       553
#            3     0.5941    0.3301    0.4244       306
#
#     accuracy                         0.5656      1220
#    macro avg     0.5877    0.5131    0.5227      1220
# weighted avg     0.5801    0.5656    0.5462      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2584    0.1465    0.1870       157
#            2     0.4412    0.6962    0.5401       237
#            3     0.3115    0.1462    0.1990       130
#
#     accuracy                         0.3950       524
#    macro avg     0.3370    0.3296    0.3087       524
# weighted avg     0.3542    0.3950    0.3497       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.546721      0.546721         0.633806
# 1   RandomForest        0.998361      0.998361         0.998367
# 2       Adaboost        0.565574      0.565574         0.580092
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.488614       0.438931     0.438931        0.378341       0.348299
# 1        0.998360       0.395038     0.395038        0.353091       0.352170
# 2        0.546164       0.395038     0.395038        0.354244       0.349666

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9907    0.8864    0.9357       361
#            2     0.8760    0.9964    0.9323       553
#            3     0.9888    0.8660    0.9233       306
#
#     accuracy                         0.9311      1220
#    macro avg     0.9518    0.9163    0.9304      1220
# weighted avg     0.9382    0.9311    0.9311      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2667    0.1783    0.2137       157
#            2     0.4392    0.6709    0.5309       237
#            3     0.1754    0.0769    0.1070       130
#
#     accuracy                         0.3760       524
#    macro avg     0.2938    0.3087    0.2839       524
# weighted avg     0.3221    0.3760    0.3307       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.546721      0.546721         0.633806
# 1   RandomForest        0.998361      0.998361         0.998367
# 2       Adaboost        0.565574      0.565574         0.580092
# 3            GBM        0.931148      0.931148         0.938235
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.488614       0.438931     0.438931        0.378341       0.348299
# 1        0.998360       0.395038     0.395038        0.353091       0.352170
# 2        0.546164       0.395038     0.395038        0.354244       0.349666
# 3        0.931060       0.375954     0.375954        0.322081       0.330688

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3656    0.5540    0.4405       361
#            2     0.5346    0.3074    0.3904       553
#            3     0.3437    0.3987    0.3691       306
#
#     accuracy                         0.4033      1220
#    macro avg     0.4146    0.4200    0.4000      1220
# weighted avg     0.4367    0.4033    0.3999      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3198    0.4522    0.3747       157
#            2     0.5127    0.3418    0.4101       237
#            3     0.2361    0.2615    0.2482       130
#
#     accuracy                         0.3550       524
#    macro avg     0.3562    0.3518    0.3443       524
# weighted avg     0.3863    0.3550    0.3593       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-20-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.545082      0.545082         0.590136
# 1   RandomForest        0.998361      0.998361         0.998361
# 2            SVM        0.403279      0.403279         0.436707
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.526927       0.349237     0.349237        0.330972       0.326065
# 1        0.998361       0.410305     0.410305        0.350129       0.340256
# 2        0.399880       0.354962     0.354962        0.386271       0.359324

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5027    0.5208    0.5116       361
#            2     0.5778    0.7523    0.6536       553
#            3     0.5635    0.2320    0.3287       306
#
#     accuracy                         0.5533      1220
#    macro avg     0.5480    0.5017    0.4979      1220
# weighted avg     0.5520    0.5533    0.5301      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2667    0.2548    0.2606       157
#            2     0.4444    0.5907    0.5072       237
#            3     0.2542    0.1154    0.1587       130
#
#     accuracy                         0.3721       524
#    macro avg     0.3218    0.3203    0.3089       524
# weighted avg     0.3440    0.3721    0.3469       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.546721      0.546721         0.633806
# 1   RandomForest        0.998361      0.998361         0.998367
# 2       Adaboost        0.565574      0.565574         0.580092
# 3            GBM        0.931148      0.931148         0.938235
# 4            SVM        0.453279      0.453279         0.205462
# 5            KNN        0.553279      0.553279         0.551971
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.488614       0.438931     0.438931        0.378341       0.348299
# 1        0.998360       0.395038     0.395038        0.353091       0.352170
# 2        0.546164       0.395038     0.395038        0.354244       0.349666
# 3        0.931060       0.375954     0.375954        0.322081       0.330688
# 4        0.282756       0.452290     0.452290        0.204566       0.281716
# 5        0.530069       0.372137     0.372137        0.343990       0.346879

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3406    0.6454    0.4459       361
#            2     0.5225    0.3562    0.4237       553
#            3     0.3208    0.1667    0.2194       306
#
#     accuracy                         0.3943      1220
#    macro avg     0.3946    0.3894    0.3630      1220
# weighted avg     0.4181    0.3943    0.3790      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3000    0.5541    0.3893       157
#            2     0.4607    0.3460    0.3952       237
#            3     0.1429    0.0615    0.0860       130
#
#     accuracy                         0.3378       524
#    macro avg     0.3012    0.3206    0.2902       524
# weighted avg     0.3337    0.3378    0.3167       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.546721      0.546721         0.633806
# 1   RandomForest        0.998361      0.998361         0.998367
# 2       Adaboost        0.565574      0.565574         0.580092
# 3            GBM        0.931148      0.931148         0.938235
# 4            SVM        0.453279      0.453279         0.205462
# 5            KNN        0.553279      0.553279         0.551971
# 6            GNB        0.394262      0.394262         0.418108
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.488614       0.438931     0.438931        0.378341       0.348299
# 1        0.998360       0.395038     0.395038        0.353091       0.352170
# 2        0.546164       0.395038     0.395038        0.354244       0.349666
# 3        0.931060       0.375954     0.375954        0.322081       0.330688
# 4        0.282756       0.452290     0.452290        0.204566       0.281716
# 5        0.530069       0.372137     0.372137        0.343990       0.346879
# 6        0.379005       0.337786     0.337786        0.333686       0.316707
