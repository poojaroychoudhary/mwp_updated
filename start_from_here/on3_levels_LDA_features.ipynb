# %% [markdown]
# LDA == Features Extracted on 3 class problem

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/bert_changedlevels.csv"
dataset = pd.read_csv(path)
dataset.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.251582  0.065441  0.036327 -0.683447 -0.864267  0.043688
# 1           1  0.307343  0.046227  0.070979 -0.689943 -0.421657 -0.045189
# 2           2  0.330305  0.214742  0.517233 -0.529509 -0.374165 -0.236629
# 3           3  0.266967  0.254776  0.249469 -0.518748 -0.460016 -0.099519
# 4           4  0.221523  0.013097 -0.097723 -1.067212 -0.829449  0.143097
#
#           6         7         8  ...       759       760       761       762  \
# 0 -0.182814 -0.056845  0.180367  ...  0.057088  0.038299  0.289821 -0.283759
# 1  0.146107 -0.190608  0.162453  ...  0.373472  0.056404  0.079221 -0.368649
# 2  0.780357 -0.248850  0.348099  ...  0.052816 -0.340460  0.361714 -0.405706
# 3  0.359582  0.087548  0.356397  ...  0.190572  0.242963  0.207410 -0.466586
# 4 -0.051330 -0.085799  0.035921  ...  0.261153 -0.027681  0.528556 -0.489401
#
# ...

# %%
dataset.drop(dataset.columns[[0]], axis=1, inplace=True)
dataset.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.251582  0.065441  0.036327 -0.683447 -0.864267  0.043688 -0.182814
# 1  0.307343  0.046227  0.070979 -0.689943 -0.421657 -0.045189  0.146107
# 2  0.330305  0.214742  0.517233 -0.529509 -0.374165 -0.236629  0.780357
# 3  0.266967  0.254776  0.249469 -0.518748 -0.460016 -0.099519  0.359582
# 4  0.221523  0.013097 -0.097723 -1.067212 -0.829449  0.143097 -0.051330
#
#           7         8         9  ...       759       760       761       762  \
# 0 -0.056845  0.180367 -0.370679  ...  0.057088  0.038299  0.289821 -0.283759
# 1 -0.190608  0.162453 -0.529358  ...  0.373472  0.056404  0.079221 -0.368649
# 2 -0.248850  0.348099 -0.530329  ...  0.052816 -0.340460  0.361714 -0.405706
# 3  0.087548  0.356397 -0.599168  ...  0.190572  0.242963  0.207410 -0.466586
# 4 -0.085799  0.035921  0.215113  ...  0.261153 -0.027681  0.528556 -0.489401
#
#         763       764       765       766       767  Level
# ...

# %%
def PreProcessing(dataset):
  #Remove First row (Indexing from Excel)
  dataset = dataset.iloc[:, 1:] 
    
  #Shuffling
  dataset = dataset.sample(frac = 1) #frac denotes the fraction of samples to be returned. 

  # distributing the dataset into two components X and Y
  X = dataset.iloc[:, 0:-1].values
  y = dataset.iloc[:, -1].values

  #Scaling (Standardization)
  sc = StandardScaler()
  X = sc.fit_transform(X)

  print(X.shape)
  print(y.shape)
  return X, y

# %%
X, y = PreProcessing(dataset)
# Out:
# (1744, 767)
# (1744,)

# %%
def LDA_fn(X, y, name):
  lda = LinearDiscriminantAnalysis(n_components = 2)
  lda.fit(X, y)
  transformed = lda.transform(X)
  print(transformed.shape)

  #Store result as csv
  temp = name+"_"+"2_features.csv"
  df1 = pd.DataFrame(transformed)
  df1.to_csv(temp) 
  files.download(temp)

# %%
LDA_fn(X, y, "bert_2lda_withstopwordchangelevels")
# Out:
# (1744, 2)

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/fasttext_changedlevels.csv"
dataset = pd.read_csv(path)
X, y = PreProcessing(dataset)
LDA_fn(X, y, "fasttext_2lda_withstopwordchangelevels")
print("___________________________________________________________________________________________________")
# Out:
# (1744, 300)
# (1744,)
# (1744, 2)
# ___________________________________________________________________________________________________

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/glove_changedlevels.csv"
dataset = pd.read_csv(path)
X, y = PreProcessing(dataset)
LDA_fn(X, y, "glove_2lda_withstopwordchangelevels")
print("___________________________________________________________________________________________________")
# Out:
# (1744, 300)
# (1744,)
# (1744, 2)
# ___________________________________________________________________________________________________

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/tfidf_changedlevels.csv"
dataset = pd.read_csv(path)
X, y = PreProcessing(dataset)
LDA_fn(X, y, "tfidf_2lda_withstopwordchangelevels")
print("___________________________________________________________________________________________________")
# Out:
# (1744, 3604)
# (1744,)
# (1744, 2)
# ___________________________________________________________________________________________________

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/w2v_changedlevels.csv"
dataset = pd.read_csv(path)
X, y = PreProcessing(dataset)
LDA_fn(X, y, "w2v_2lda_withstopwordchangelevels")
print("___________________________________________________________________________________________________")
# Out:
# (1744, 300)
# (1744,)
# (1744, 2)
# ___________________________________________________________________________________________________
