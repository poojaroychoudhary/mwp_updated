# %% [markdown]
# Anova_w2v_200features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np 
import pandas as pd 
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_W2v/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_W2v/w2v_withstopwordchangelevels_200_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.316651  0.320247 -1.215047 -0.204455  0.959906  0.471685
# 1           1  0.463912 -1.052838  1.500506 -0.123902  0.178576  1.573959
# 2           2 -0.200795 -0.034359  1.362814 -1.082017 -2.352423 -1.077118
# 3           3 -0.588976  1.482890 -1.546697  0.135782  0.571578 -1.171519
# 4           4  0.186963 -0.454802 -0.109622  0.627314  1.152559 -0.490801
#
#           6         7         8  ...       190       191       192       193  \
# 0 -0.745187 -0.297845 -0.006231  ...  0.927530 -0.142684 -0.297041 -0.292038
# 1  1.072436 -0.461929  0.965129  ...  0.316264 -0.794911  0.318127  0.748199
# 2  0.352338  0.840759  0.177580  ...  0.689127  1.849300 -0.713403  0.352379
# 3  0.016514 -0.149843 -0.433210  ...  0.019403 -0.220683  0.136476 -0.849842
# 4 -1.570882  0.508141 -1.104757  ...  0.744618  0.608311  0.272750  0.194078
#
#         194       195       196       197       198       199
# 0 -0.179030  0.978015 -0.999766 -1.435071 -0.237499  0.181093
# 1  1.509728 -0.577566  1.081517  0.585866 -0.739232 -0.617290
# 2 -1.002875  1.246759 -0.462861 -1.210556  0.632867  0.425530
# 3 -0.474510 -0.655113 -0.107667 -0.401983  0.344306  0.210401
# 4  0.693689  1.183283 -0.230617 -0.963051  0.571213  0.895070
#
# [5 rows x 201 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.316651  0.320247 -1.215047 -0.204455  0.959906  0.471685 -0.745187
# 1  0.463912 -1.052838  1.500506 -0.123902  0.178576  1.573959  1.072436
# 2 -0.200795 -0.034359  1.362814 -1.082017 -2.352423 -1.077118  0.352338
# 3 -0.588976  1.482890 -1.546697  0.135782  0.571578 -1.171519  0.016514
# 4  0.186963 -0.454802 -0.109622  0.627314  1.152559 -0.490801 -1.570882
#
#           7         8         9  ...       190       191       192       193  \
# 0 -0.297845 -0.006231  0.105926  ...  0.927530 -0.142684 -0.297041 -0.292038
# 1 -0.461929  0.965129  0.023427  ...  0.316264 -0.794911  0.318127  0.748199
# 2  0.840759  0.177580  0.590205  ...  0.689127  1.849300 -0.713403  0.352379
# 3 -0.149843 -0.433210  0.035981  ...  0.019403 -0.220683  0.136476 -0.849842
# 4  0.508141 -1.104757  0.000366  ...  0.744618  0.608311  0.272750  0.194078
#
#         194       195       196       197       198       199
# 0 -0.179030  0.978015 -0.999766 -1.435071 -0.237499  0.181093
# 1  1.509728 -0.577566  1.081517  0.585866 -0.739232 -0.617290
# 2 -1.002875  1.246759 -0.462861 -1.210556  0.632867  0.425530
# 3 -0.474510 -0.655113 -0.107667 -0.401983  0.344306  0.210401
# 4  0.693689  1.183283 -0.230617 -0.963051  0.571213  0.895070
#
# [5 rows x 200 columns]

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 200), (524, 200))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.3016516553485685

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.464754      0.464754         0.526136
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.454991       0.299618     0.299618         0.35432       0.292601

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9972    0.9972    0.9972       361
#            2     1.0000    0.9964    0.9982       553
#            3     0.9903    0.9967    0.9935       306
#
#     accuracy                         0.9967      1220
#    macro avg     0.9958    0.9968    0.9963      1220
# weighted avg     0.9967    0.9967    0.9967      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3108    0.1465    0.1991       157
#            2     0.4475    0.7553    0.5620       237
#            3     0.3000    0.1154    0.1667       130
#
#     accuracy                         0.4141       524
#    macro avg     0.3528    0.3391    0.3093       524
# weighted avg     0.3700    0.4141    0.3552       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.464754      0.464754         0.526136
# 1   RandomForest        0.996721      0.996721         0.996737
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.454991       0.299618     0.299618        0.354320       0.292601
# 1        0.996725       0.414122     0.414122        0.369952       0.355204

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5765    0.4072    0.4773       361
#            2     0.5733    0.7920    0.6651       553
#            3     0.6070    0.3987    0.4813       306
#
#     accuracy                         0.5795      1220
#    macro avg     0.5856    0.5326    0.5412      1220
# weighted avg     0.5827    0.5795    0.5634      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3299    0.2038    0.2520       157
#            2     0.4428    0.6203    0.5167       237
#            3     0.2421    0.1769    0.2044       130
#
#     accuracy                         0.3855       524
#    macro avg     0.3383    0.3337    0.3244       524
# weighted avg     0.3592    0.3855    0.3599       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.584426      0.584426         0.644962
# 1   RandomForest        0.996721      0.996721         0.996725
# 2       Adaboost        0.579508      0.579508         0.582681
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.546169       0.370229     0.370229        0.319183       0.312438
# 1        0.996718       0.406489     0.406489        0.369024       0.362605
# 2        0.563433       0.385496     0.385496        0.359168       0.359912

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9907    0.8864    0.9357       361
#            2     0.8558    0.9982    0.9215       553
#            3     0.9841    0.8105    0.8889       306
#
#     accuracy                         0.9180      1220
#    macro avg     0.9436    0.8984    0.9154      1220
# weighted avg     0.9279    0.9180    0.9175      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3247    0.1592    0.2137       157
#            2     0.4645    0.7173    0.5638       237
#            3     0.2716    0.1692    0.2085       130
#
#     accuracy                         0.4141       524
#    macro avg     0.3536    0.3486    0.3287       524
# weighted avg     0.3747    0.4141    0.3708       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.584426      0.584426         0.644962
# 1   RandomForest        0.996721      0.996721         0.996725
# 2       Adaboost        0.579508      0.579508         0.582681
# 3            GBM        0.918033      0.918033         0.927914
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.546169       0.370229     0.370229        0.319183       0.312438
# 1        0.996718       0.406489     0.406489        0.369024       0.362605
# 2        0.563433       0.385496     0.385496        0.359168       0.359912
# 3        0.917530       0.414122     0.414122        0.374742       0.370778

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3741    0.4321    0.4010       361
#            2     0.5564    0.3834    0.4540       553
#            3     0.3507    0.4837    0.4066       306
#
#     accuracy                         0.4230      1220
#    macro avg     0.4271    0.4331    0.4205      1220
# weighted avg     0.4509    0.4230    0.4264      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2805    0.2930    0.2866       157
#            2     0.4024    0.2785    0.3292       237
#            3     0.2500    0.3769    0.3006       130
#
#     accuracy                         0.3073       524
#    macro avg     0.3110    0.3161    0.3055       524
# weighted avg     0.3281    0.3073    0.3093       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.464754      0.464754         0.526136
# 1   RandomForest        0.996721      0.996721         0.996737
# 2            SVM        0.422951      0.422951         0.450880
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.454991       0.299618     0.299618        0.354320       0.292601
# 1        0.996725       0.414122     0.414122        0.369952       0.355204
# 2        0.426418       0.307252     0.307252        0.328081       0.309335

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5518    0.4571    0.5000       361
#            2     0.5799    0.7939    0.6702       553
#            3     0.5244    0.2810    0.3660       306
#
#     accuracy                         0.5656      1220
#    macro avg     0.5521    0.5107    0.5121      1220
# weighted avg     0.5577    0.5656    0.5435      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2240    0.1783    0.1986       157
#            2     0.4451    0.6160    0.5168       237
#            3     0.1831    0.1000    0.1294       130
#
#     accuracy                         0.3569       524
#    macro avg     0.2841    0.2981    0.2816       524
# weighted avg     0.3139    0.3569    0.3253       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.584426      0.584426         0.644962
# 1   RandomForest        0.996721      0.996721         0.996725
# 2       Adaboost        0.579508      0.579508         0.582681
# 3            GBM        0.918033      0.918033         0.927914
# 4            SVM        0.453279      0.453279         0.205462
# 5            KNN        0.565574      0.565574         0.557683
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.546169       0.370229     0.370229        0.319183       0.312438
# 1        0.996718       0.406489     0.406489        0.369024       0.362605
# 2        0.563433       0.385496     0.385496        0.359168       0.359912
# 3        0.917530       0.414122     0.414122        0.374742       0.370778
# 4        0.282756       0.452290     0.452290        0.204566       0.281716
# 5        0.543541       0.356870     0.356870        0.313864       0.325340

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4068    0.0665    0.1143       361
#            2     0.4732    0.7505    0.5804       553
#            3     0.3063    0.2843    0.2949       306
#
#     accuracy                         0.4311      1220
#    macro avg     0.3954    0.3671    0.3299      1220
# weighted avg     0.4117    0.4311    0.3709      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2941    0.0318    0.0575       157
#            2     0.4321    0.6709    0.5256       237
#            3     0.2662    0.2846    0.2751       130
#
#     accuracy                         0.3836       524
#    macro avg     0.3308    0.3291    0.2861       524
# weighted avg     0.3496    0.3836    0.3232       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.584426      0.584426         0.644962
# 1   RandomForest        0.996721      0.996721         0.996725
# 2       Adaboost        0.579508      0.579508         0.582681
# 3            GBM        0.918033      0.918033         0.927914
# 4            SVM        0.453279      0.453279         0.205462
# 5            KNN        0.565574      0.565574         0.557683
# 6            GNB        0.431148      0.431148         0.411696
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.546169       0.370229     0.370229        0.319183       0.312438
# 1        0.996718       0.406489     0.406489        0.369024       0.362605
# 2        0.563433       0.385496     0.385496        0.359168       0.359912
# 3        0.917530       0.414122     0.414122        0.374742       0.370778
# 4        0.282756       0.452290     0.452290        0.204566       0.281716
# 5        0.543541       0.356870     0.356870        0.313864       0.325340
# 6        0.370880       0.383588     0.383588        0.349581       0.323200
