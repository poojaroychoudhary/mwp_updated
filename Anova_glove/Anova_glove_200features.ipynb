# %% [markdown]
# Anova_glove_200features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np 
import pandas as pd
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_Glove/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_Glove/glove_withstopwordchangelevels_200_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.305057  1.451480  0.234614  0.983526 -0.666804  0.046993
# 1           1  1.099880 -0.714018 -1.590730  0.361006 -0.443806 -1.209345
# 2           2 -0.641502 -1.736616 -0.080492  0.456267  0.150446 -1.009223
# 3           3  1.422019 -1.658173  0.780231  1.045841  0.113203 -1.407687
# 4           4 -0.463694 -0.791213 -0.149811  0.822247 -1.000989 -0.374022
#
#           6         7         8  ...       190       191       192       193  \
# 0  0.829017  0.282336 -1.614043  ... -0.587859  0.891468  0.791283  1.024896
# 1  0.388135 -0.363254  0.225297  ...  0.811491  0.837622  1.973062 -0.082170
# 2 -0.005192  1.292458  0.338288  ... -0.453109 -0.909240  1.761161  0.501431
# 3  1.925675  0.996404  0.943571  ...  1.458682  0.899712  0.203948 -1.342319
# 4  0.443648 -0.865694  0.217664  ...  0.880555 -1.054308 -0.416271 -0.569182
#
#         194       195       196       197       198       199
# 0 -0.438181  1.290849  0.884474  0.182868  0.606349 -1.108464
# 1 -1.214911 -1.126616  0.801091 -0.992655 -1.324648  0.256543
# 2  1.396330  0.312043  1.105622  0.456868  0.077940 -0.279190
# 3 -0.673343  0.920110  0.005259  1.479388  0.034223 -0.546118
# 4  0.052792 -0.168018  0.999755  0.297784  0.019293 -1.220615
#
# [5 rows x 201 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.305057  1.451480  0.234614  0.983526 -0.666804  0.046993  0.829017
# 1  1.099880 -0.714018 -1.590730  0.361006 -0.443806 -1.209345  0.388135
# 2 -0.641502 -1.736616 -0.080492  0.456267  0.150446 -1.009223 -0.005192
# 3  1.422019 -1.658173  0.780231  1.045841  0.113203 -1.407687  1.925675
# 4 -0.463694 -0.791213 -0.149811  0.822247 -1.000989 -0.374022  0.443648
#
#           7         8         9  ...       190       191       192       193  \
# 0  0.282336 -1.614043 -1.034391  ... -0.587859  0.891468  0.791283  1.024896
# 1 -0.363254  0.225297  1.195050  ...  0.811491  0.837622  1.973062 -0.082170
# 2  1.292458  0.338288  0.350049  ... -0.453109 -0.909240  1.761161  0.501431
# 3  0.996404  0.943571  0.757580  ...  1.458682  0.899712  0.203948 -1.342319
# 4 -0.865694  0.217664 -0.227554  ...  0.880555 -1.054308 -0.416271 -0.569182
#
#         194       195       196       197       198       199
# 0 -0.438181  1.290849  0.884474  0.182868  0.606349 -1.108464
# 1 -1.214911 -1.126616  0.801091 -0.992655 -1.324648  0.256543
# 2  1.396330  0.312043  1.105622  0.456868  0.077940 -0.279190
# 3 -0.673343  0.920110  0.005259  1.479388  0.034223 -0.546118
# 4  0.052792 -0.168018  0.999755  0.297784  0.019293 -1.220615
#
# [5 rows x 200 columns]

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 200), (524, 200))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.38772730734585276

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.494262      0.494262         0.536026
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.500025       0.337786     0.337786        0.368431       0.340043

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9586    0.9612    0.9599       361
#            2     0.9817    0.9693    0.9754       553
#            3     0.9551    0.9739    0.9644       306
#
#     accuracy                         0.9680      1220
#    macro avg     0.9651    0.9681    0.9666      1220
# weighted avg     0.9682    0.9680    0.9681      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2903    0.1146    0.1644       157
#            2     0.4512    0.8397    0.5870       237
#            3     0.3333    0.0538    0.0927       130
#
#     accuracy                         0.4275       524
#    macro avg     0.3583    0.3361    0.2814       524
# weighted avg     0.3738    0.4275    0.3378       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.494262      0.494262         0.536026
# 1   RandomForest        0.968033      0.968033         0.968182
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.500025       0.337786     0.337786        0.368431       0.340043
# 1        0.968066       0.427481     0.427481        0.373778       0.337758

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5992    0.4017    0.4809       361
#            2     0.5408    0.7794    0.6385       553
#            3     0.5580    0.3301    0.4148       306
#
#     accuracy                         0.5549      1220
#    macro avg     0.5660    0.5037    0.5114      1220
# weighted avg     0.5624    0.5549    0.5358      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3173    0.2102    0.2529       157
#            2     0.4380    0.6414    0.5205       237
#            3     0.2466    0.1385    0.1773       130
#
#     accuracy                         0.3874       524
#    macro avg     0.3340    0.3300    0.3169       524
# weighted avg     0.3544    0.3874    0.3552       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.554918      0.554918         0.627510
# 1   RandomForest        0.968033      0.968033         0.968128
# 2       Adaboost        0.554918      0.554918         0.562380
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.488627       0.437023     0.437023        0.384392       0.354576
# 1        0.968003       0.412214     0.412214        0.371583       0.341368
# 2        0.535771       0.387405     0.387405        0.354366       0.355201

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9558    0.8975    0.9257       361
#            2     0.9070    0.9873    0.9455       553
#            3     0.9749    0.8889    0.9299       306
#
#     accuracy                         0.9361      1220
#    macro avg     0.9459    0.9246    0.9337      1220
# weighted avg     0.9384    0.9361    0.9357      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3364    0.2293    0.2727       157
#            2     0.4426    0.6835    0.5373       237
#            3     0.2157    0.0846    0.1215       130
#
#     accuracy                         0.3989       524
#    macro avg     0.3316    0.3325    0.3105       524
# weighted avg     0.3545    0.3989    0.3549       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.554918      0.554918         0.627510
# 1   RandomForest        0.968033      0.968033         0.968128
# 2       Adaboost        0.554918      0.554918         0.562380
# 3            GBM        0.936066      0.936066         0.938449
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.488627       0.437023     0.437023        0.384392       0.354576
# 1        0.968003       0.412214     0.412214        0.371583       0.341368
# 2        0.535771       0.387405     0.387405        0.354366       0.355201
# 3        0.935716       0.398855     0.398855        0.354510       0.354890

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5442    0.6648    0.5985       361
#            2     0.7366    0.5208    0.6102       553
#            3     0.5284    0.6699    0.5908       306
#
#     accuracy                         0.6008      1220
#    macro avg     0.6030    0.6185    0.5998      1220
# weighted avg     0.6274    0.6008    0.6019      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3188    0.4204    0.3626       157
#            2     0.4556    0.3460    0.3933       237
#            3     0.2336    0.2462    0.2397       130
#
#     accuracy                         0.3435       524
#    macro avg     0.3360    0.3375    0.3319       524
# weighted avg     0.3595    0.3435    0.3460       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.494262      0.494262         0.536026
# 1   RandomForest        0.968033      0.968033         0.968182
# 2            SVM        0.600820      0.600820         0.627428
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.500025       0.337786     0.337786        0.368431       0.340043
# 1        0.968066       0.427481     0.427481        0.373778       0.337758
# 2        0.601854       0.343511     0.343511        0.359522       0.346000

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5134    0.5291    0.5211       361
#            2     0.5857    0.7107    0.6422       553
#            3     0.5650    0.3268    0.4141       306
#
#     accuracy                         0.5607      1220
#    macro avg     0.5547    0.5222    0.5258      1220
# weighted avg     0.5591    0.5607    0.5491      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3145    0.3185    0.3165       157
#            2     0.4845    0.5949    0.5341       237
#            3     0.3108    0.1769    0.2255       130
#
#     accuracy                         0.4084       524
#    macro avg     0.3699    0.3634    0.3587       524
# weighted avg     0.3905    0.4084    0.3923       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.554918      0.554918         0.627510
# 1   RandomForest        0.968033      0.968033         0.968128
# 2       Adaboost        0.554918      0.554918         0.562380
# 3            GBM        0.936066      0.936066         0.938449
# 4            SVM        0.632787      0.632787         0.632861
# 5            KNN        0.560656      0.560656         0.559116
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.488627       0.437023     0.437023        0.384392       0.354576
# 1        0.968003       0.412214     0.412214        0.371583       0.341368
# 2        0.535771       0.387405     0.387405        0.354366       0.355201
# 3        0.935716       0.398855     0.398855        0.354510       0.354890
# 4        0.625228       0.372137     0.372137        0.350601       0.356306
# 5        0.549143       0.408397     0.408397        0.390480       0.392322

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4109    0.2936    0.3425       361
#            2     0.5583    0.2857    0.3780       553
#            3     0.2916    0.6471    0.4020       306
#
#     accuracy                         0.3787      1220
#    macro avg     0.4203    0.4088    0.3742      1220
# weighted avg     0.4478    0.3787    0.3735      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2975    0.2293    0.2590       157
#            2     0.4659    0.1730    0.2523       237
#            3     0.2540    0.6154    0.3596       130
#
#     accuracy                         0.2996       524
#    macro avg     0.3391    0.3392    0.2903       524
# weighted avg     0.3629    0.2996    0.2809       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.554918      0.554918         0.627510
# 1   RandomForest        0.968033      0.968033         0.968128
# 2       Adaboost        0.554918      0.554918         0.562380
# 3            GBM        0.936066      0.936066         0.938449
# 4            SVM        0.632787      0.632787         0.632861
# 5            KNN        0.560656      0.560656         0.559116
# 6            GNB        0.378689      0.378689         0.447780
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.488627       0.437023     0.437023        0.384392       0.354576
# 1        0.968003       0.412214     0.412214        0.371583       0.341368
# 2        0.535771       0.387405     0.387405        0.354366       0.355201
# 3        0.935716       0.398855     0.398855        0.354510       0.354890
# 4        0.625228       0.372137     0.372137        0.350601       0.356306
# 5        0.549143       0.408397     0.408397        0.390480       0.392322
# 6        0.373515       0.299618     0.299618        0.362876       0.280917
