# %% [markdown]
# Anova_w2v_250features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np 
import pandas as pd
from sklearn import preprocessing 
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_W2v/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_W2v/w2v_withstopwordchangelevels_250_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -0.259914  0.789074 -0.716431  0.621554 -0.011284  0.058829
# 1           1 -0.263502 -0.475565 -1.259387  0.731601  1.049571 -1.061531
# 2           2 -0.466462  0.666503 -0.812523  0.644894  0.264271 -0.659888
# 3           3 -0.126703 -0.049136  0.356653 -0.248089  1.758264  1.164960
# 4           4 -0.193630  0.773572 -0.939427  0.379502  1.014308  0.169748
#
#           6         7         8  ...       240       241       242       243  \
# 0  0.137288 -1.039544 -0.651220  ... -0.798675 -1.437802 -0.499258  0.887208
# 1 -0.993382  0.085194 -1.344923  ... -0.211675  0.747671  1.365071  0.239698
# 2  0.241572 -0.729632 -0.461957  ...  0.022326 -0.570073  0.446836 -0.081854
# 3  0.519203 -1.089622  0.826345  ...  0.309150 -0.283024  0.319584 -1.155386
# 4  0.414037 -0.949696  0.134930  ... -0.096043 -1.028905  0.115719  0.109835
#
#         244       245       246       247       248       249
# 0  0.061290 -0.656662  0.949912  0.850549  0.798095  1.127691
# 1  0.883994 -0.427482  0.244016  0.220105 -0.216760  0.452456
# 2  0.349103 -0.250831  0.405765  0.096306 -0.438933  0.309239
# 3 -0.760229 -0.054940  0.744615  0.093833 -0.567137  0.172543
# 4 -0.363808 -0.649121  1.479465  0.602563  0.182053 -0.155789
#
# [5 rows x 251 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.259914  0.789074 -0.716431  0.621554 -0.011284  0.058829  0.137288
# 1 -0.263502 -0.475565 -1.259387  0.731601  1.049571 -1.061531 -0.993382
# 2 -0.466462  0.666503 -0.812523  0.644894  0.264271 -0.659888  0.241572
# 3 -0.126703 -0.049136  0.356653 -0.248089  1.758264  1.164960  0.519203
# 4 -0.193630  0.773572 -0.939427  0.379502  1.014308  0.169748  0.414037
#
#           7         8         9  ...       240       241       242       243  \
# 0 -1.039544 -0.651220  0.406771  ... -0.798675 -1.437802 -0.499258  0.887208
# 1  0.085194 -1.344923  0.008246  ... -0.211675  0.747671  1.365071  0.239698
# 2 -0.729632 -0.461957 -0.388653  ...  0.022326 -0.570073  0.446836 -0.081854
# 3 -1.089622  0.826345  1.403618  ...  0.309150 -0.283024  0.319584 -1.155386
# 4 -0.949696  0.134930  0.697983  ... -0.096043 -1.028905  0.115719  0.109835
#
#         244       245       246       247       248       249
# 0  0.061290 -0.656662  0.949912  0.850549  0.798095  1.127691
# 1  0.883994 -0.427482  0.244016  0.220105 -0.216760  0.452456
# 2  0.349103 -0.250831  0.405765  0.096306 -0.438933  0.309239
# 3 -0.760229 -0.054940  0.744615  0.093833 -0.567137  0.172543
# 4 -0.363808 -0.649121  1.479465  0.602563  0.182053 -0.155789
#
# [5 rows x 250 columns]

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 250), (524, 250))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.35983628399623935

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.481967      0.481967         0.658852
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0         0.46737       0.307252     0.307252        0.401669       0.284926

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     1.0000    0.9972    0.9986       361
#            2     0.9982    1.0000    0.9991       553
#            3     1.0000    1.0000    1.0000       306
#
#     accuracy                         0.9992      1220
#    macro avg     0.9994    0.9991    0.9992      1220
# weighted avg     0.9992    0.9992    0.9992      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3077    0.1529    0.2043       157
#            2     0.4482    0.7300    0.5554       237
#            3     0.1833    0.0846    0.1158       130
#
#     accuracy                         0.3969       524
#    macro avg     0.3131    0.3225    0.2918       524
# weighted avg     0.3404    0.3969    0.3411       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.481967      0.481967         0.658852
# 1   RandomForest        0.999180      0.999180         0.999182
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0         0.46737       0.307252     0.307252        0.401669       0.284926
# 1         0.99918       0.396947     0.396947        0.340384       0.341117

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6009    0.3712    0.4589       361
#            2     0.5491    0.8083    0.6540       553
#            3     0.6393    0.3824    0.4785       306
#
#     accuracy                         0.5721      1220
#    macro avg     0.5965    0.5206    0.5305      1220
# weighted avg     0.5871    0.5721    0.5523      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3579    0.2166    0.2698       157
#            2     0.4741    0.7342    0.5762       237
#            3     0.2581    0.1231    0.1667       130
#
#     accuracy                         0.4275       524
#    macro avg     0.3634    0.3579    0.3376       524
# weighted avg     0.3857    0.4275    0.3828       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.535246      0.535246         0.608100
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.572131      0.572131         0.587080
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.473013       0.438931     0.438931        0.395335       0.360396
# 1        0.999181       0.389313     0.389313        0.339270       0.340406
# 2        0.552253       0.427481     0.427481        0.385693       0.382789

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9715    0.9446    0.9579       361
#            2     0.9240    0.9892    0.9555       553
#            3     0.9856    0.8922    0.9365       306
#
#     accuracy                         0.9516      1220
#    macro avg     0.9604    0.9420    0.9500      1220
# weighted avg     0.9535    0.9516    0.9514      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3366    0.2166    0.2636       157
#            2     0.4517    0.6709    0.5399       237
#            3     0.2254    0.1231    0.1592       130
#
#     accuracy                         0.3989       524
#    macro avg     0.3379    0.3368    0.3209       524
# weighted avg     0.3611    0.3989    0.3627       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.535246      0.535246         0.608100
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.572131      0.572131         0.587080
# 3            GBM        0.951639      0.951639         0.953493
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.473013       0.438931     0.438931        0.395335       0.360396
# 1        0.999181       0.389313     0.389313        0.339270       0.340406
# 2        0.552253       0.427481     0.427481        0.385693       0.382789
# 3        0.951424       0.398855     0.398855        0.361071       0.362657

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3619    0.4792    0.4124       361
#            2     0.5742    0.4268    0.4896       553
#            3     0.3444    0.3725    0.3579       306
#
#     accuracy                         0.4287      1220
#    macro avg     0.4268    0.4262    0.4200      1220
# weighted avg     0.4538    0.4287    0.4337      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3231    0.4713    0.3834       157
#            2     0.4630    0.3165    0.3759       237
#            3     0.2782    0.2846    0.2814       130
#
#     accuracy                         0.3550       524
#    macro avg     0.3548    0.3575    0.3469       524
# weighted avg     0.3752    0.3550    0.3547       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.481967      0.481967         0.658852
# 1   RandomForest        0.999180      0.999180         0.999182
# 2            SVM        0.428689      0.428689         0.453756
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.467370       0.307252     0.307252        0.401669       0.284926
# 1        0.999180       0.396947     0.396947        0.340384       0.341117
# 2        0.433741       0.354962     0.354962        0.375231       0.354719

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4908    0.5152    0.5027       361
#            2     0.6040    0.7089    0.6522       553
#            3     0.4531    0.2843    0.3494       306
#
#     accuracy                         0.5451      1220
#    macro avg     0.5160    0.5028    0.5014      1220
# weighted avg     0.5327    0.5451    0.5320      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3605    0.3949    0.3769       157
#            2     0.4739    0.5359    0.5030       237
#            3     0.2381    0.1538    0.1869       130
#
#     accuracy                         0.3989       524
#    macro avg     0.3575    0.3615    0.3556       524
# weighted avg     0.3814    0.3989    0.3868       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.535246      0.535246         0.608100
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.572131      0.572131         0.587080
# 3            GBM        0.951639      0.951639         0.953493
# 4            SVM        0.452459      0.452459         0.289916
# 5            KNN        0.545082      0.545082         0.532654
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.473013       0.438931     0.438931        0.395335       0.360396
# 1        0.999181       0.389313     0.389313        0.339270       0.340406
# 2        0.552253       0.427481     0.427481        0.385693       0.382789
# 3        0.951424       0.398855     0.398855        0.361071       0.362657
# 4        0.289061       0.448473     0.448473        0.511458       0.286648
# 5        0.532036       0.398855     0.398855        0.381403       0.386787

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3921    0.2465    0.3027       361
#            2     0.4815    0.6600    0.5568       553
#            3     0.3319    0.2549    0.2884       306
#
#     accuracy                         0.4361      1220
#    macro avg     0.4018    0.3872    0.3826      1220
# weighted avg     0.4175    0.4361    0.4143      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3505    0.2166    0.2677       157
#            2     0.4795    0.6414    0.5487       237
#            3     0.2909    0.2462    0.2667       130
#
#     accuracy                         0.4160       524
#    macro avg     0.3736    0.3680    0.3610       524
# weighted avg     0.3941    0.4160    0.3946       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.535246      0.535246         0.608100
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.572131      0.572131         0.587080
# 3            GBM        0.951639      0.951639         0.953493
# 4            SVM        0.452459      0.452459         0.289916
# 5            KNN        0.545082      0.545082         0.532654
# 6            GNB        0.436066      0.436066         0.417533
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.473013       0.438931     0.438931        0.395335       0.360396
# 1        0.999181       0.389313     0.389313        0.339270       0.340406
# 2        0.552253       0.427481     0.427481        0.385693       0.382789
# 3        0.951424       0.398855     0.398855        0.361071       0.362657
# 4        0.289061       0.448473     0.448473        0.511458       0.286648
# 5        0.532036       0.398855     0.398855        0.381403       0.386787
# 6        0.414298       0.416031     0.416031        0.394064       0.394559
