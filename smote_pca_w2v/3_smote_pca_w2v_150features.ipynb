# %% [markdown]
# Smote_pca_features

# %%
from google.colab import drive
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np 
from imblearn.over_sampling import SMOTE 
from sklearn.model_selection import KFold 
from sklearn import metrics
from tensorflow.keras.utils import to_categorical
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn import svm
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# **Models**

# %%
def Decision_tree_classifier(X_train, y_train, X_test, y_test):
  # Create Decision Tree classifer object
  clf = DecisionTreeClassifier(class_weight = "balanced")

  # Train Decision Tree Classifer
  clf = clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)

  print("Decision Tree Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("Decision Tree F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def GNB_classifier (X_train, y_train, X_test, y_test):
  #Create a Gaussian Classifier
  gnb = GaussianNB()

  #Train the model using the training sets
  gnb.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = gnb.predict(X_test)

  print("Gaussian Naive Bayes Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("Gaussian Naive Bayes F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def KNN_classifier (X_train, y_train, X_test, y_test):
  #Create KNN Classifier
  knn = KNeighborsClassifier(n_neighbors=5)

  #Train the model using the training sets
  knn.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = knn.predict(X_test)

  print("KNN Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("KNN F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def svm_classifier (X_train, y_train, X_test, y_test):
  #Create a Support Vector Machine Classifier
  clf = svm.SVC(kernel='linear', class_weight = "balanced") # Linear Kernel

  #Train the model using the training sets
  clf.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)

  print("SVM Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("SVM F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def random_forest_classifier (X_train, y_train, X_test, y_test):
  #Create a Gaussian Classifier
  clf=RandomForestClassifier(n_estimators=100, class_weight = "balanced")

  #Train the model using the training sets y_pred=clf.predict(X_test)
  clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred=clf.predict(X_test)
  print("RF Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("RF F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def ada_boost_classifier (X_train, y_train, X_test, y_test):
  # Create adaboost classifer object
  abc = AdaBoostClassifier(n_estimators=50,
                          learning_rate=1)
  # Train Adaboost Classifer
  model = abc.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = model.predict(X_test)

  print("Ada-Boost Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("Ada-Boost F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def gradient_boost_classifier (X_train, y_train, X_test, y_test):
  # Create adaboost classifer object
  gbc = GradientBoostingClassifier(n_estimators=50,
                          learning_rate=1)
  # Train Adaboost Classifer
  model = gbc.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = model.predict(X_test)

  print("Gradient-Boost Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("Gradient-Boost F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/smote_pca_w2v/data.csv"
df3 = pd.read_csv(path)
df3.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df3.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df3.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df3['Level '] = pd.cut(df3["Level "],bins,labels = group_names)

# %%
df3.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df3['Level '] = df3['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df3.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/smote_pca_w2v/w2v_withstopwordchangelevels_150_features.csv"
df2 = pd.read_csv(path)
df2.head()
# Out:
#    Unnamed: 0          0          1         2         3         4         5  \
# 0           0   5.719816   3.753577 -7.270468 -6.683765 -2.429075  1.618299
# 1           1  17.746299 -13.330659 -9.330557  1.143561 -1.791711  4.704435
# 2           2  -2.226274   1.718558 -2.493961  0.407887 -0.487651 -0.096254
# 3           3 -11.682953   2.388827  1.861568 -1.603650 -2.558248  1.741855
# 4           4  -4.725348   1.352140 -8.217170 -0.507472  0.542053 -8.566001
#
#           6         7         8  ...           140           141  \
# 0 -5.832024 -2.125934 -1.753451  ... -1.328400e-08  1.600552e-07
# 1 -2.671869  3.445507 -5.427289  ... -6.000920e-09  3.735713e-08
# 2  2.220553  0.864598 -0.678770  ... -3.324168e-08  1.154838e-07
# 3 -4.619755  2.287277  1.682215  ... -3.479320e-08  2.182697e-07
# 4  3.370496 -2.786307  4.873884  ... -7.991142e-08  6.000083e-08
#
#             142           143           144           145           146  \
# 0  3.656112e-07 -1.258745e-08 -6.595957e-08  8.024780e-08 -1.015240e-07
# 1 -2.350416e-07  1.218062e-08 -9.182038e-08  2.500201e-07  1.289237e-07
# 2  3.844717e-09  1.408011e-07 -1.446384e-08 -7.978240e-08 -1.742395e-07
# 3  7.724274e-08 -1.965868e-07  1.005511e-08  7.704525e-08 -2.705252e-07
# 4 -2.809470e-07  9.844024e-09 -2.478792e-07 -1.749872e-07 -8.114737e-08
#
#             147           148           149
# 0  1.652006e-07  5.482539e-09  4.632340e-08
# 1 -5.152249e-08 -6.788565e-08  5.411288e-08
# 2 -2.444011e-08 -7.276425e-08  1.078987e-07
# 3  1.175403e-07  1.636219e-07 -3.528624e-07
# 4 -4.760530e-08  2.542054e-07  8.378963e-08
#
# [5 rows x 151 columns]

# %%
df2.drop(df2.columns[[0]], axis=1, inplace=True)
df2.head()
# Out:
#            0          1         2         3         4         5         6  \
# 0   5.719816   3.753577 -7.270468 -6.683765 -2.429075  1.618299 -5.832024
# 1  17.746299 -13.330659 -9.330557  1.143561 -1.791711  4.704435 -2.671869
# 2  -2.226274   1.718558 -2.493961  0.407887 -0.487651 -0.096254  2.220553
# 3 -11.682953   2.388827  1.861568 -1.603650 -2.558248  1.741855 -4.619755
# 4  -4.725348   1.352140 -8.217170 -0.507472  0.542053 -8.566001  3.370496
#
#           7         8         9  ...           140           141  \
# 0 -2.125934 -1.753451 -1.195281  ... -1.328400e-08  1.600552e-07
# 1  3.445507 -5.427289 -1.576950  ... -6.000920e-09  3.735713e-08
# 2  0.864598 -0.678770  3.692568  ... -3.324168e-08  1.154838e-07
# 3  2.287277  1.682215 -0.036047  ... -3.479320e-08  2.182697e-07
# 4 -2.786307  4.873884 -0.821005  ... -7.991142e-08  6.000083e-08
#
#             142           143           144           145           146  \
# 0  3.656112e-07 -1.258745e-08 -6.595957e-08  8.024780e-08 -1.015240e-07
# 1 -2.350416e-07  1.218062e-08 -9.182038e-08  2.500201e-07  1.289237e-07
# 2  3.844717e-09  1.408011e-07 -1.446384e-08 -7.978240e-08 -1.742395e-07
# 3  7.724274e-08 -1.965868e-07  1.005511e-08  7.704525e-08 -2.705252e-07
# 4 -2.809470e-07  9.844024e-09 -2.478792e-07 -1.749872e-07 -8.114737e-08
#
#             147           148           149
# 0  1.652006e-07  5.482539e-09  4.632340e-08
# 1 -5.152249e-08 -6.788565e-08  5.411288e-08
# 2 -2.444011e-08 -7.276425e-08  1.078987e-07
# 3  1.175403e-07  1.636219e-07 -3.528624e-07
# 4 -4.760530e-08  2.542054e-07  8.378963e-08
#
# [5 rows x 150 columns]

# %%
df2['Level'] = df3['Level '].values
df2.head()
# Out:
#            0          1         2         3         4         5         6  \
# 0   5.719816   3.753577 -7.270468 -6.683765 -2.429075  1.618299 -5.832024
# 1  17.746299 -13.330659 -9.330557  1.143561 -1.791711  4.704435 -2.671869
# 2  -2.226274   1.718558 -2.493961  0.407887 -0.487651 -0.096254  2.220553
# 3 -11.682953   2.388827  1.861568 -1.603650 -2.558248  1.741855 -4.619755
# 4  -4.725348   1.352140 -8.217170 -0.507472  0.542053 -8.566001  3.370496
#
#           7         8         9  ...           141           142  \
# 0 -2.125934 -1.753451 -1.195281  ...  1.600552e-07  3.656112e-07
# 1  3.445507 -5.427289 -1.576950  ...  3.735713e-08 -2.350416e-07
# 2  0.864598 -0.678770  3.692568  ...  1.154838e-07  3.844717e-09
# 3  2.287277  1.682215 -0.036047  ...  2.182697e-07  7.724274e-08
# 4 -2.786307  4.873884 -0.821005  ...  6.000083e-08 -2.809470e-07
#
#             143           144           145           146           147  \
# 0 -1.258745e-08 -6.595957e-08  8.024780e-08 -1.015240e-07  1.652006e-07
# 1  1.218062e-08 -9.182038e-08  2.500201e-07  1.289237e-07 -5.152249e-08
# 2  1.408011e-07 -1.446384e-08 -7.978240e-08 -1.742395e-07 -2.444011e-08
# 3 -1.965868e-07  1.005511e-08  7.704525e-08 -2.705252e-07  1.175403e-07
# 4  9.844024e-09 -2.478792e-07 -1.749872e-07 -8.114737e-08 -4.760530e-08
#
#             148           149  Level
# 0  5.482539e-09  4.632340e-08      3
# 1 -6.788565e-08  5.411288e-08      3
# 2 -7.276425e-08  1.078987e-07      3
# 3  1.636219e-07 -3.528624e-07      3
# 4  2.542054e-07  8.378963e-08      1
#
# [5 rows x 151 columns]

# %%
 #Data Shuffling
df2 = df2.sample(frac = 1) #frac denotes the fraction of samples to be returned. 

 
#train-test split
trdata = df2.sample(frac=0.7, random_state=25) #Training data = 70%
tsdata = df2.drop(trdata.index) #Testing data = 30%
X_train = trdata.iloc[:,:-1]
y_train = trdata.iloc[:,-1]
X_test = tsdata.iloc[:,:-1]
y_test = tsdata.iloc[:,-1]

#SMOTE
sm = SMOTE()
X_train, y_train = sm.fit_resample(X_train, y_train.ravel())

# %%
  #Model Calling
  Decision_tree_classifier(X_train, y_train, X_test, y_test)
  GNB_classifier(X_train, y_train, X_test, y_test)
  KNN_classifier(X_train, y_train, X_test, y_test) 
  svm_classifier(X_train, y_train, X_test, y_test)
  random_forest_classifier(X_train, y_train, X_test, y_test)
  ada_boost_classifier(X_train, y_train, X_test, y_test)
  gradient_boost_classifier(X_train, y_train, X_test, y_test)
  perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Decision Tree Accuracy: 0.3690248565965583
# Decision Tree F1 Score: 0.3711892703948034
# Gaussian Naive Bayes Accuracy: 0.3575525812619503
# Gaussian Naive Bayes F1 Score: 0.33808678099460976
# KNN Accuracy: 0.35946462715105165
# KNN F1 Score: 0.36193014514578914
# SVM Accuracy: 0.3422562141491396
# SVM F1 Score: 0.34106284171270723
# RF Accuracy: 0.40152963671128106
# RF F1 Score: 0.38755480469561915
# Ada-Boost Accuracy: 0.33460803059273425
# Ada-Boost F1 Score: 0.3367739324253009
# Gradient-Boost Accuracy: 0.34990439770554493
# Gradient-Boost F1 Score: 0.35200032992226415
# Perceptron F1 score: 0.28969063151509344
