# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np 
import pandas as pd 
from sklearn import preprocessing 
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/autoencoder_features/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/autoencoder_features/w2v_2autoencode_withstopwordchangelevels_20_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.028356 -0.027343 -0.043408  0.046483  0.042634 -0.042684
# 1           1 -0.027614 -0.023253  0.015664  0.035162  0.073077 -0.004681
# 2           2 -0.007114 -0.030609 -0.016998  0.021180  0.008782 -0.022955
# 3           3 -0.036786  0.023975  0.042512  0.056861  0.027843  0.062048
# 4           4 -0.062032  0.031629 -0.008311  0.046735  0.008590  0.018913
#
#           6         7         8  ...        10        11        12        13  \
# 0 -0.013113 -0.015544  0.052242  ...  0.056964 -0.023859  0.021969 -0.021171
# 1 -0.033987  0.013166 -0.021408  ... -0.046242 -0.023640  0.011998 -0.038361
# 2 -0.030152  0.010713 -0.030342  ...  0.032674 -0.043951  0.012793 -0.046727
# 3 -0.019043 -0.031062  0.020103  ... -0.041298  0.051937 -0.022421  0.050132
# 4 -0.027661 -0.029437 -0.048229  ... -0.005416 -0.046874  0.034071 -0.002846
#
#          14        15        16        17        18        19
# 0  0.058027 -0.036890 -0.058765  0.005255 -0.003495 -0.046744
# 1 -0.044711 -0.018649 -0.027628 -0.025628 -0.026541  0.010643
# 2 -0.003832 -0.059905  0.032911  0.051636 -0.013341  0.038275
# 3  0.071465 -0.007935  0.009239 -0.029448 -0.050665 -0.000839
# 4  0.012694  0.041272  0.034830 -0.020116  0.007270  0.012544
#
# [5 rows x 21 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.028356 -0.027343 -0.043408  0.046483  0.042634 -0.042684 -0.013113
# 1 -0.027614 -0.023253  0.015664  0.035162  0.073077 -0.004681 -0.033987
# 2 -0.007114 -0.030609 -0.016998  0.021180  0.008782 -0.022955 -0.030152
# 3 -0.036786  0.023975  0.042512  0.056861  0.027843  0.062048 -0.019043
# 4 -0.062032  0.031629 -0.008311  0.046735  0.008590  0.018913 -0.027661
#
#           7         8         9        10        11        12        13  \
# 0 -0.015544  0.052242 -0.019761  0.056964 -0.023859  0.021969 -0.021171
# 1  0.013166 -0.021408  0.019343 -0.046242 -0.023640  0.011998 -0.038361
# 2  0.010713 -0.030342  0.021423  0.032674 -0.043951  0.012793 -0.046727
# 3 -0.031062  0.020103  0.010609 -0.041298  0.051937 -0.022421  0.050132
# 4 -0.029437 -0.048229  0.014633 -0.005416 -0.046874  0.034071 -0.002846
#
#          14        15        16        17        18        19
# 0  0.058027 -0.036890 -0.058765  0.005255 -0.003495 -0.046744
# 1 -0.044711 -0.018649 -0.027628 -0.025628 -0.026541  0.010643
# 2 -0.003832 -0.059905  0.032911  0.051636 -0.013341  0.038275
# 3  0.071465 -0.007935  0.009239 -0.029448 -0.050665 -0.000839
# 4  0.012694  0.041272  0.034830 -0.020116  0.007270  0.012544

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 20), (524, 20))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.3975535168195719

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.537705      0.537705         0.571943
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.493668       0.375954     0.375954        0.305183       0.305025

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     1.0000    1.0000    1.0000       361
#            2     1.0000    1.0000    1.0000       553
#            3     1.0000    1.0000    1.0000       306
#
#     accuracy                         1.0000      1220
#    macro avg     1.0000    1.0000    1.0000      1220
# weighted avg     1.0000    1.0000    1.0000      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3243    0.0764    0.1237       157
#            2     0.4414    0.8734    0.5864       237
#            3     0.1667    0.0231    0.0405       130
#
#     accuracy                         0.4237       524
#    macro avg     0.3108    0.3243    0.2502       524
# weighted avg     0.3381    0.4237    0.3123       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.537705      0.537705         0.571943
# 1   RandomForest        1.000000      1.000000         1.000000
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.493668       0.375954     0.375954        0.305183       0.305025
# 1        1.000000       0.423664     0.423664        0.338147       0.312348

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5020    0.3407    0.4059       361
#            2     0.5239    0.7939    0.6312       553
#            3     0.5255    0.2353    0.3251       306
#
#     accuracy                         0.5197      1220
#    macro avg     0.5172    0.4566    0.4541      1220
# weighted avg     0.5178    0.5197    0.4878      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2240    0.1783    0.1986       157
#            2     0.4382    0.6582    0.5261       237
#            3     0.2093    0.0692    0.1040       130
#
#     accuracy                         0.3683       524
#    macro avg     0.2905    0.3019    0.2763       524
# weighted avg     0.3172    0.3683    0.3233       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-23-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.523770      0.523770         0.612363
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.519672      0.519672         0.517830
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.437224       0.400763     0.400763        0.283759       0.294547
# 1        1.000000       0.398855     0.398855        0.329444       0.319172
# 2        0.487759       0.368321     0.368321        0.317235       0.323279

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9500    0.7368    0.8300       361
#            2     0.7284    0.9892    0.8390       553
#            3     0.9894    0.6111    0.7556       306
#
#     accuracy                         0.8197      1220
#    macro avg     0.8893    0.7790    0.8082      1220
# weighted avg     0.8594    0.8197    0.8154      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2627    0.1975    0.2255       157
#            2     0.4516    0.7089    0.5517       237
#            3     0.2059    0.0538    0.0854       130
#
#     accuracy                         0.3931       524
#    macro avg     0.3067    0.3201    0.2875       524
# weighted avg     0.3341    0.3931    0.3383       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-23-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.523770      0.523770         0.612363
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.519672      0.519672         0.517830
# 3            GBM        0.819672      0.819672         0.859423
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.437224       0.400763     0.400763        0.283759       0.294547
# 1        1.000000       0.398855     0.398855        0.329444       0.319172
# 2        0.487759       0.368321     0.368321        0.317235       0.323279
# 3        0.815374       0.393130     0.393130        0.334051       0.338268

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.0000    0.0000    0.0000       361
#            2     0.0000    0.0000    0.0000       553
#            3     0.2508    1.0000    0.4010       306
#
#     accuracy                         0.2508      1220
#    macro avg     0.0836    0.3333    0.1337      1220
# weighted avg     0.0629    0.2508    0.1006      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.0000    0.0000    0.0000       157
#            2     0.0000    0.0000    0.0000       237
#            3     0.2481    1.0000    0.3976       130
#
#     accuracy                         0.2481       524
#    macro avg     0.0827    0.3333    0.1325       524
# weighted avg     0.0615    0.2481    0.0986       524
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.537705      0.537705         0.571943
# 1   RandomForest        1.000000      1.000000         1.000000
# 2            SVM        0.250820      0.250820         0.062911
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.493668       0.375954     0.375954        0.305183       0.305025
# 1        1.000000       0.423664     0.423664        0.338147       0.312348
# 2        0.100591       0.248092     0.248092        0.061549       0.098630

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4773    0.5540    0.5128       361
#            2     0.5896    0.7197    0.6482       553
#            3     0.5238    0.2157    0.3056       306
#
#     accuracy                         0.5443      1220
#    macro avg     0.5303    0.4965    0.4889      1220
# weighted avg     0.5399    0.5443    0.5222      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2634    0.3121    0.2857       157
#            2     0.4496    0.5274    0.4854       237
#            3     0.3000    0.1385    0.1895       130
#
#     accuracy                         0.3664       524
#    macro avg     0.3377    0.3260    0.3202       524
# weighted avg     0.3567    0.3664    0.3522       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-23-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.523770      0.523770         0.612363
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.519672      0.519672         0.517830
# 3            GBM        0.819672      0.819672         0.859423
# 4            SVM        0.453279      0.453279         0.205462
# 5            KNN        0.544262      0.544262         0.539890
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.437224       0.400763     0.400763        0.283759       0.294547
# 1        1.000000       0.398855     0.398855        0.329444       0.319172
# 2        0.487759       0.368321     0.368321        0.317235       0.323279
# 3        0.815374       0.393130     0.393130        0.334051       0.338268
# 4        0.282756       0.452290     0.452290        0.204566       0.281716
# 5        0.522203       0.366412     0.366412        0.356727       0.352170

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5147    0.0970    0.1632       361
#            2     0.4649    0.9349    0.6210       553
#            3     0.5250    0.0686    0.1214       306
#
#     accuracy                         0.4697      1220
#    macro avg     0.5015    0.3668    0.3019      1220
# weighted avg     0.4947    0.4697    0.3602      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2273    0.0318    0.0559       157
#            2     0.4481    0.9283    0.6044       237
#            3     0.1818    0.0154    0.0284       130
#
#     accuracy                         0.4332       524
#    macro avg     0.2857    0.3252    0.2295       524
# weighted avg     0.3159    0.4332    0.2971       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-23-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.523770      0.523770         0.612363
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.519672      0.519672         0.517830
# 3            GBM        0.819672      0.819672         0.859423
# 4            SVM        0.453279      0.453279         0.205462
# 5            KNN        0.544262      0.544262         0.539890
# 6            GNB        0.469672      0.469672         0.494725
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.437224       0.400763     0.400763        0.283759       0.294547
# 1        1.000000       0.398855     0.398855        0.329444       0.319172
# 2        0.487759       0.368321     0.368321        0.317235       0.323279
# 3        0.815374       0.393130     0.393130        0.334051       0.338268
# 4        0.282756       0.452290     0.452290        0.204566       0.281716
# 5        0.522203       0.366412     0.366412        0.356727       0.352170
# 6        0.360224       0.433206     0.433206        0.315858       0.297139
