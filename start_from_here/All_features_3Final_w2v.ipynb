# %% [markdown]
# Final Word2Vec

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np
import pandas as pd
from sklearn import preprocessing 
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import logging
import pandas as pd
import numpy as np
import gensim
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import re
from bs4 import BeautifulSoup
import csv
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from scipy.stats import kurtosis
from scipy.stats import skew
from scipy.stats import gmean

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
#STOPWORDS =nltk.corpus.stopwords.words('english')

def clean_text(text):
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split())                                            # if word not in STOPWORDS) # delete stopwors from text
    return text

# %%
from gensim.models import KeyedVectors

# %%
pip install --upgrade gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.22.4)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.3.0)

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/GoogleNews-vectors-negative300.bin"

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
def sent_vectorizer(sent, model):
  sent_vec =[]
  numw = 0
  for w in sent:
    try:
      if numw == 0:
        sent_vec = model[w]
      else:
        sent_vec = np.add(sent_vec, model[w])
      numw+=1
    except:
      pass
  return np.asarray(sent_vec) / numw

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,0] = df.iloc[:,0].apply(clean_text)
print(df.iloc[:100,0])
# Out:
# <ipython-input-5-13f1ba12ea11>:6: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, "lxml").text # HTML decoding
# 0     there are constants alpha and beta such that f...
# 1     the length of the segment between the points 2...
# 2     chewbacca has 20 pieces of cherry gum and 30 p...
# 3     for some constants a and b let f x left begin ...
# 4         calculate the sum 1 + 3 + 5 + cdots + 15 + 17
#                             ...
# 95    what is the largest value of x that satisfies ...
# 96    what is the sum of left dfrac 1 3 right + left...
# 97    on a map a 12centimeter length represents 72 k...
# 98    find the sum of all values of x such that 2 x2...
# 99    given that a 0 if f g a 8 where f x x2 + 8 and...
# Name: Problem , Length: 100, dtype: object

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
#STOPWORDS =nltk.corpus.stopwords.words('english')

# %%
def clean_text(text):
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split())                                    # if word not in STOPWORDS) # delete stopwors from text
    return text

# %%
d = [];
for sent in df.iloc[:,0]:
  d.append(sent_vectorizer(sent, wv))

# %%
x = pd.DataFrame(d)
x
# Out:
#            0         1         2         3         4         5         6    \
# 0    -0.132192  0.085008 -0.021770  0.104603 -0.064176  0.014193 -0.075376
# 1    -0.169962  0.117862 -0.023319  0.127086 -0.067426  0.011222 -0.069913
# 2    -0.178082  0.116493  0.005438  0.142175 -0.040640  0.008901 -0.113469
# 3    -0.186971  0.112337 -0.010057  0.114066 -0.043843  0.023473 -0.094416
# 4    -0.089071  0.038916 -0.012351  0.113045 -0.067452 -0.006399 -0.105726
# ...        ...       ...       ...       ...       ...       ...       ...
# 1739 -0.171463  0.116479 -0.019951  0.130252 -0.067947  0.004469 -0.068196
# 1740 -0.025483 -0.036655  0.034297  0.132129 -0.038510  0.026529 -0.050878
# 1741 -0.189193  0.097619 -0.014453  0.119201 -0.063216  0.004088 -0.076057
# 1742 -0.142863  0.079657 -0.001976  0.132881 -0.068677  0.037540 -0.088348
# 1743 -0.117626  0.072355  0.012596  0.118730 -0.038111  0.018932 -0.055638
#
#            7         8         9    ...       290       291       292  \
# 0    -0.062582  0.017596  0.029619  ...  0.057682  0.009523 -0.101325
# 1    -0.051933 -0.023587  0.024029  ...  0.068842 -0.015122 -0.104072
# 2    -0.031516 -0.040196  0.012933  ...  0.087883 -0.034578 -0.112262
# 3    -0.034772 -0.009186  0.032829  ...  0.065617  0.023958 -0.077597
# 4    -0.109937  0.010508  0.025785  ...  0.062809  0.050385 -0.114153
# ...        ...       ...       ...  ...       ...       ...       ...
# 1739 -0.045648 -0.025267  0.027248  ...  0.072647 -0.005521 -0.095367
# 1740 -0.095410  0.048145  0.062163  ...  0.062651  0.070950 -0.136068
# 1741 -0.055443  0.002574  0.029337  ...  0.068118  0.057751 -0.089679
# 1742 -0.086886 -0.000564  0.017924  ...  0.074267  0.013669 -0.089999
# 1743 -0.046074  0.001320  0.041728  ...  0.051197  0.018421 -0.109505
#
#            293       294       295       296       297       298       299
# 0     0.114898 -0.016636 -0.134433 -0.144924 -0.050143 -0.100066  0.150123
# 1     0.097132 -0.028843 -0.158527 -0.118772 -0.044826 -0.101228  0.156272
# 2     0.085987 -0.023003 -0.151592 -0.108893 -0.009504 -0.111104  0.170099
# 3     0.094924 -0.026164 -0.149806 -0.128227 -0.046681 -0.124457  0.143542
# 4     0.091296 -0.032458 -0.111222 -0.134111 -0.048697 -0.090511  0.148385
# ...        ...       ...       ...       ...       ...       ...       ...
# 1739  0.108589 -0.030199 -0.154041 -0.150093 -0.045092 -0.112608  0.146539
# 1740  0.072793 -0.016992 -0.043027 -0.153506 -0.059006 -0.115166  0.088845
# 1741  0.079035 -0.032185 -0.166989 -0.146279 -0.041569 -0.108601  0.132403
# 1742  0.114263 -0.022890 -0.146598 -0.122286 -0.051984 -0.105588  0.160139
# 1743  0.108959 -0.038931 -0.123591 -0.130953 -0.044358 -0.102033  0.116894
#
# [1744 rows x 300 columns]

# %%
from google.colab import files
x.to_csv('w2v_levelsrecode.csv') 
files.download('w2v_levelsrecode.csv')

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/w2v_levelsrecode.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -0.132192  0.085008 -0.021770  0.104603 -0.064176  0.014193
# 1           1 -0.169962  0.117862 -0.023319  0.127086 -0.067426  0.011222
# 2           2 -0.178082  0.116493  0.005438  0.142175 -0.040640  0.008901
# 3           3 -0.186971  0.112337 -0.010057  0.114066 -0.043843  0.023473
# 4           4 -0.089071  0.038916 -0.012351  0.113045 -0.067452 -0.006399
#
#           6         7         8  ...       290       291       292       293  \
# 0 -0.075376 -0.062582  0.017596  ...  0.057682  0.009523 -0.101325  0.114898
# 1 -0.069913 -0.051933 -0.023587  ...  0.068842 -0.015122 -0.104072  0.097132
# 2 -0.113469 -0.031516 -0.040196  ...  0.087883 -0.034578 -0.112262  0.085987
# 3 -0.094416 -0.034772 -0.009186  ...  0.065617  0.023958 -0.077597  0.094924
# 4 -0.105726 -0.109937  0.010508  ...  0.062809  0.050385 -0.114153  0.091296
#
#         294       295       296       297       298       299
# 0 -0.016636 -0.134433 -0.144924 -0.050143 -0.100066  0.150123
# 1 -0.028843 -0.158527 -0.118772 -0.044826 -0.101228  0.156272
# 2 -0.023003 -0.151592 -0.108893 -0.009504 -0.111104  0.170099
# 3 -0.026164 -0.149806 -0.128227 -0.046681 -0.124457  0.143542
# 4 -0.032458 -0.111222 -0.134111 -0.048697 -0.090511  0.148385
#
# [5 rows x 301 columns]

# %%
y=df['Level ']

# %%
x.shape
# Out:
# (1744, 301)

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 301), (524, 301))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train) 
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.3975535168195719

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.572951      0.572951         0.659738
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.566787       0.433206     0.433206        0.514183       0.423034

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     1.0000    1.0000    1.0000       361
#            2     1.0000    1.0000    1.0000       553
#            3     1.0000    1.0000    1.0000       306
#
#     accuracy                         1.0000      1220
#    macro avg     1.0000    1.0000    1.0000      1220
# weighted avg     1.0000    1.0000    1.0000      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6160    0.4904    0.5461       157
#            2     0.5245    0.7679    0.6233       237
#            3     0.6538    0.2615    0.3736       130
#
#     accuracy                         0.5592       524
#    macro avg     0.5981    0.5066    0.5143       524
# weighted avg     0.5840    0.5592    0.5382       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.572951      0.572951         0.659738
# 1   RandomForest        1.000000      1.000000         1.000000
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.566787       0.433206     0.433206        0.514183       0.423034
# 1        1.000000       0.559160     0.559160        0.584003       0.538222

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6910    0.5512    0.6133       361
#            2     0.5447    0.6727    0.6019       553
#            3     0.5904    0.4804    0.5297       306
#
#     accuracy                         0.5885      1220
#    macro avg     0.6087    0.5681    0.5816      1220
# weighted avg     0.5994    0.5885    0.5872      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4924    0.4140    0.4498       157
#            2     0.5017    0.6118    0.5513       237
#            3     0.4757    0.3769    0.4206       130
#
#     accuracy                         0.4943       524
#    macro avg     0.4900    0.4676    0.4739       524
# weighted avg     0.4925    0.4943    0.4885       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-36-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.577869      0.577869         0.603205
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.588525      0.588525         0.599415
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.578176       0.444656     0.444656        0.456722       0.444055
# 1        1.000000       0.524809     0.524809        0.530692       0.504280
# 2        0.587176       0.494275     0.494275        0.492491       0.488485

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9942    0.9529    0.9731       361
#            2     0.9564    0.9928    0.9743       553
#            3     0.9767    0.9575    0.9670       306
#
#     accuracy                         0.9721      1220
#    macro avg     0.9758    0.9677    0.9715      1220
# weighted avg     0.9727    0.9721    0.9721      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5468    0.4841    0.5135       157
#            2     0.4967    0.6414    0.5599       237
#            3     0.4937    0.3000    0.3732       130
#
#     accuracy                         0.5095       524
#    macro avg     0.5124    0.4751    0.4822       524
# weighted avg     0.5110    0.5095    0.4997       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-36-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.577869      0.577869         0.603205
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.588525      0.588525         0.599415
# 3            GBM        0.972131      0.972131         0.972695
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.578176       0.444656     0.444656        0.456722       0.444055
# 1        1.000000       0.524809     0.524809        0.530692       0.504280
# 2        0.587176       0.494275     0.494275        0.492491       0.488485
# 3        0.972106       0.509542     0.509542        0.510963       0.499663

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5070    0.4017    0.4482       361
#            2     0.5780    0.1808    0.2755       553
#            3     0.3193    0.7941    0.4555       306
#
#     accuracy                         0.4000      1220
#    macro avg     0.4681    0.4589    0.3931      1220
# weighted avg     0.4921    0.4000    0.3717      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5351    0.3885    0.4502       157
#            2     0.4819    0.1688    0.2500       237
#            3     0.3150    0.7923    0.4508       130
#
#     accuracy                         0.3893       524
#    macro avg     0.4440    0.4499    0.3837       524
# weighted avg     0.4564    0.3893    0.3598       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.572951      0.572951         0.659738
# 1   RandomForest        1.000000      1.000000         1.000000
# 2            SVM        0.400000      0.400000         0.492122
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.566787       0.433206     0.433206        0.514183       0.423034
# 1        1.000000       0.559160     0.559160        0.584003       0.538222
# 2        0.371744       0.389313     0.389313        0.456438       0.359787

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6721    0.5734    0.6188       361
#            2     0.6198    0.7342    0.6722       553
#            3     0.6070    0.5098    0.5542       306
#
#     accuracy                         0.6303      1220
#    macro avg     0.6330    0.6058    0.6151      1220
# weighted avg     0.6321    0.6303    0.6268      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5669    0.4586    0.5070       157
#            2     0.5123    0.6160    0.5594       237
#            3     0.3929    0.3385    0.3636       130
#
#     accuracy                         0.5000       524
#    macro avg     0.4907    0.4710    0.4767       524
# weighted avg     0.4990    0.5000    0.4951       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-36-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.577869      0.577869         0.603205
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.588525      0.588525         0.599415
# 3            GBM        0.972131      0.972131         0.972695
# 4            SVM        0.470492      0.470492         0.450984
# 5            KNN        0.630328      0.630328         0.632081
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.578176       0.444656     0.444656        0.456722       0.444055
# 1        1.000000       0.524809     0.524809        0.530692       0.504280
# 2        0.587176       0.494275     0.494275        0.492491       0.488485
# 3        0.972106       0.509542     0.509542        0.510963       0.499663
# 4        0.325548       0.465649     0.465649        0.421534       0.318406
# 5        0.626799       0.500000     0.500000        0.499026       0.495139

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4470    0.3269    0.3776       361
#            2     0.4556    0.1483    0.2237       553
#            3     0.3119    0.7908    0.4473       306
#
#     accuracy                         0.3623      1220
#    macro avg     0.4048    0.4220    0.3496      1220
# weighted avg     0.4170    0.3623    0.3253      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5179    0.3694    0.4312       157
#            2     0.4500    0.1139    0.1818       237
#            3     0.3040    0.8231    0.4440       130
#
#     accuracy                         0.3664       524
#    macro avg     0.4239    0.4355    0.3523       524
# weighted avg     0.4341    0.3664    0.3216       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-36-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.577869      0.577869         0.603205
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.588525      0.588525         0.599415
# 3            GBM        0.972131      0.972131         0.972695
# 4            SVM        0.470492      0.470492         0.450984
# 5            KNN        0.630328      0.630328         0.632081
# 6            GNB        0.362295      0.362295         0.416972
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.578176       0.444656     0.444656        0.456722       0.444055
# 1        1.000000       0.524809     0.524809        0.530692       0.504280
# 2        0.587176       0.494275     0.494275        0.492491       0.488485
# 3        0.972106       0.509542     0.509542        0.510963       0.499663
# 4        0.325548       0.465649     0.465649        0.421534       0.318406
# 5        0.626799       0.500000     0.500000        0.499026       0.495139
# 6        0.325345       0.366412     0.366412        0.434104       0.321587
