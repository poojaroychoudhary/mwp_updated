# %% [markdown]
# Anova_fasttext_100 features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np
import pandas as pd
from sklearn import preprocessing 
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer 
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_Fastext/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_Fastext/fasttext_withstopwordchangelevels_100_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.049969 -1.057798  1.022324 -0.230176  0.911229 -1.076854
# 1           1 -0.629538 -0.869730 -0.596976  0.235357  0.686049 -1.187746
# 2           2 -0.454156 -0.894368  0.253086  1.162268  0.827293  0.034907
# 3           3  0.227372  1.198687 -0.169574 -0.681808  1.212654  1.588631
# 4           4 -0.609153 -0.886714 -0.431465 -0.195277  0.267854 -0.557226
#
#           6         7         8  ...        90        91        92        93  \
# 0  0.488826  0.107998 -0.307052  ... -1.013724  0.794322 -1.292337  0.812376
# 1  0.317137 -0.083047  0.335945  ... -0.101758  0.953805 -0.419154  0.396731
# 2 -0.211353  0.375582  0.786643  ...  0.480966  0.247184 -0.394096  0.183039
# 3 -1.149103 -1.359572 -2.328948  ... -1.171122  1.747864  2.349965 -0.957827
# 4 -0.649871  0.559685 -0.441459  ...  0.401725 -0.477020  0.684734  1.033921
#
#          94        95        96        97        98        99
# 0 -0.208378 -1.188586 -0.018014 -0.047962 -0.309242 -0.108298
# 1 -0.631454 -0.483901 -0.428319 -0.313120 -0.624784 -0.012939
# 2  0.318909 -0.489601  0.431713 -0.432009  0.492619  0.775961
# 3  2.135194  1.973600  0.020198 -0.182964 -0.666994 -1.458585
# 4 -0.697217 -0.731568  0.219302  0.774395 -0.160900  0.710849
#
# [5 rows x 101 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.049969 -1.057798  1.022324 -0.230176  0.911229 -1.076854  0.488826
# 1 -0.629538 -0.869730 -0.596976  0.235357  0.686049 -1.187746  0.317137
# 2 -0.454156 -0.894368  0.253086  1.162268  0.827293  0.034907 -0.211353
# 3  0.227372  1.198687 -0.169574 -0.681808  1.212654  1.588631 -1.149103
# 4 -0.609153 -0.886714 -0.431465 -0.195277  0.267854 -0.557226 -0.649871
#
#           7         8         9  ...        90        91        92        93  \
# 0  0.107998 -0.307052 -0.346317  ... -1.013724  0.794322 -1.292337  0.812376
# 1 -0.083047  0.335945 -0.813651  ... -0.101758  0.953805 -0.419154  0.396731
# 2  0.375582  0.786643 -0.379268  ...  0.480966  0.247184 -0.394096  0.183039
# 3 -1.359572 -2.328948  0.526496  ... -1.171122  1.747864  2.349965 -0.957827
# 4  0.559685 -0.441459 -0.550128  ...  0.401725 -0.477020  0.684734  1.033921
#
#          94        95        96        97        98        99
# 0 -0.208378 -1.188586 -0.018014 -0.047962 -0.309242 -0.108298
# 1 -0.631454 -0.483901 -0.428319 -0.313120 -0.624784 -0.012939
# 2  0.318909 -0.489601  0.431713 -0.432009  0.492619  0.775961
# 3  2.135194  1.973600  0.020198 -0.182964 -0.666994 -1.458585
# 4 -0.697217 -0.731568  0.219302  0.774395 -0.160900  0.710849
#
# [5 rows x 100 columns]

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 100), (524, 100))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test) 
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.3949491555981921

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.457377      0.457377         0.511303
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.449693       0.278626     0.278626        0.312198       0.271705

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9972    1.0000    0.9986       361
#            2     1.0000    1.0000    1.0000       553
#            3     1.0000    0.9967    0.9984       306
#
#     accuracy                         0.9992      1220
#    macro avg     0.9991    0.9989    0.9990      1220
# weighted avg     0.9992    0.9992    0.9992      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2535    0.1146    0.1579       157
#            2     0.4447    0.7806    0.5666       237
#            3     0.3243    0.0923    0.1437       130
#
#     accuracy                         0.4103       524
#    macro avg     0.3409    0.3292    0.2894       524
# weighted avg     0.3576    0.4103    0.3392       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.457377      0.457377         0.511303
# 1   RandomForest        0.999180      0.999180         0.999183
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.449693       0.278626     0.278626        0.312198       0.271705
# 1        0.999180       0.410305     0.410305        0.357560       0.339237

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6062    0.4349    0.5065       361
#            2     0.5796    0.8228    0.6801       553
#            3     0.5909    0.3399    0.4315       306
#
#     accuracy                         0.5869      1220
#    macro avg     0.5922    0.5325    0.5394      1220
# weighted avg     0.5903    0.5869    0.5664      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3333    0.2293    0.2717       157
#            2     0.4362    0.6203    0.5122       237
#            3     0.2405    0.1462    0.1818       130
#
#     accuracy                         0.3855       524
#    macro avg     0.3367    0.3319    0.3219       524
# weighted avg     0.3568    0.3855    0.3582       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.515574      0.515574         0.575591
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.586885      0.586885         0.590309
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.435026       0.402672     0.402672        0.293740       0.304101
# 1        0.999180       0.417939     0.417939        0.376833       0.363063
# 2        0.566381       0.385496     0.385496        0.356830       0.358174

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9564    0.9114    0.9333       361
#            2     0.8716    0.9946    0.9291       553
#            3     0.9918    0.7941    0.8820       306
#
#     accuracy                         0.9197      1220
#    macro avg     0.9400    0.9000    0.9148      1220
# weighted avg     0.9269    0.9197    0.9185      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2708    0.1656    0.2055       157
#            2     0.4250    0.6456    0.5126       237
#            3     0.3529    0.1846    0.2424       130
#
#     accuracy                         0.3874       524
#    macro avg     0.3496    0.3319    0.3202       524
# weighted avg     0.3609    0.3874    0.3536       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.515574      0.515574         0.575591
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.586885      0.586885         0.590309
# 3            GBM        0.919672      0.919672         0.926863
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.435026       0.402672     0.402672        0.293740       0.304101
# 1        0.999180       0.417939     0.417939        0.376833       0.363063
# 2        0.566381       0.385496     0.385496        0.356830       0.358174
# 3        0.918526       0.387405     0.387405        0.360932       0.353552

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4028    0.5512    0.4655       361
#            2     0.5585    0.4141    0.4756       553
#            3     0.3639    0.3758    0.3698       306
#
#     accuracy                         0.4451      1220
#    macro avg     0.4418    0.4471    0.4370      1220
# weighted avg     0.4637    0.4451    0.4461      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3182    0.4013    0.3549       157
#            2     0.4696    0.3586    0.4067       237
#            3     0.2828    0.3154    0.2982       130
#
#     accuracy                         0.3607       524
#    macro avg     0.3569    0.3584    0.3533       524
# weighted avg     0.3779    0.3607    0.3643       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.457377      0.457377         0.511303
# 1   RandomForest        0.999180      0.999180         0.999183
# 2            SVM        0.445082      0.445082         0.463651
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.449693       0.278626     0.278626        0.312198       0.271705
# 1        0.999180       0.410305     0.410305        0.357560       0.339237
# 2        0.446066       0.360687     0.360687        0.377885       0.364266

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5242    0.5097    0.5169       361
#            2     0.5838    0.7559    0.6588       553
#            3     0.5098    0.2549    0.3399       306
#
#     accuracy                         0.5574      1220
#    macro avg     0.5393    0.5068    0.5052      1220
# weighted avg     0.5476    0.5574    0.5368      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2550    0.2420    0.2484       157
#            2     0.4337    0.5654    0.4908       237
#            3     0.2424    0.1231    0.1633       130
#
#     accuracy                         0.3588       524
#    macro avg     0.3104    0.3102    0.3008       524
# weighted avg     0.3327    0.3588    0.3369       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.515574      0.515574         0.575591
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.586885      0.586885         0.590309
# 3            GBM        0.919672      0.919672         0.926863
# 4            SVM        0.454918      0.454918         0.356426
# 5            KNN        0.557377      0.557377         0.547609
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.435026       0.402672     0.402672        0.293740       0.304101
# 1        0.999180       0.417939     0.417939        0.376833       0.363063
# 2        0.566381       0.385496     0.385496        0.356830       0.358174
# 3        0.918526       0.387405     0.387405        0.360932       0.353552
# 4        0.287882       0.454198     0.454198        0.453049       0.285874
# 5        0.536798       0.358779     0.358779        0.332695       0.336923

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3185    0.6759    0.4330       361
#            2     0.5856    0.2351    0.3355       553
#            3     0.3233    0.2451    0.2788       306
#
#     accuracy                         0.3680      1220
#    macro avg     0.4091    0.3854    0.3491      1220
# weighted avg     0.4408    0.3680    0.3501      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3154    0.5987    0.4132       157
#            2     0.4174    0.2025    0.2727       237
#            3     0.2432    0.2077    0.2241       130
#
#     accuracy                         0.3225       524
#    macro avg     0.3254    0.3363    0.3033       524
# weighted avg     0.3436    0.3225    0.3027       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.515574      0.515574         0.575591
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.586885      0.586885         0.590309
# 3            GBM        0.919672      0.919672         0.926863
# 4            SVM        0.454918      0.454918         0.356426
# 5            KNN        0.557377      0.557377         0.547609
# 6            GNB        0.368033      0.368033         0.440773
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.435026       0.402672     0.402672        0.293740       0.304101
# 1        0.999180       0.417939     0.417939        0.376833       0.363063
# 2        0.566381       0.385496     0.385496        0.356830       0.358174
# 3        0.918526       0.387405     0.387405        0.360932       0.353552
# 4        0.287882       0.454198     0.454198        0.453049       0.285874
# 5        0.536798       0.358779     0.358779        0.332695       0.336923
# 6        0.350127       0.322519     0.322519        0.343639       0.302739
