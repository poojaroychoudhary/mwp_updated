# %% [markdown]
# Fast Text

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np
import pandas as pd 
from sklearn import preprocessing 
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import StratifiedShuffleSplit

# %%
import nltk
nltk.download('stopwords')
import re
from bs4 import BeautifulSoup
import numpy as np
import torch
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from gensim.models import KeyedVectors
from gensim.test.utils import datapath
import logging
import gensim
import csv

# %%
# !pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.22.4)

# %%
# !pip install fastText
import fasttext
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fastText in /usr/local/lib/python3.10/dist-packages (0.9.2)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.10/dist-packages (from fastText) (2.10.4)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from fastText) (67.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fastText) (1.22.4)

# %%
from gensim.models.fasttext import FastText

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/wiki-news-300d-1M.vec"

# %%
en_model = KeyedVectors.load_word2vec_format(path)

# %%
# !pip install transformers 
import transformers as ppb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 62.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 48.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.29.2

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High'] 
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head(5)
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
#STOPWORDS =nltk.corpus.stopwords.words('english')

# %%
def clean_text(text):
    text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split())                                                                      #if word not in STOPWORDS) # delete stopwors from text
    return text

# %%
a=en_model['king'] #Example
a
# Out:
# array([ 1.082e-01,  4.450e-02, -3.840e-02,  1.100e-03, -8.880e-02,
#         7.130e-02, -6.960e-02, -4.770e-02,  7.100e-03, -4.080e-02,
#        -7.070e-02, -2.660e-02,  5.000e-02, -8.240e-02,  8.480e-02,
#        -1.627e-01, -8.510e-02, -2.950e-02,  1.534e-01, -1.828e-01,
#        -2.208e-01,  2.430e-02, -9.210e-02, -1.089e-01, -1.009e-01,
#        -1.190e-02,  3.770e-02,  2.038e-01,  7.200e-02,  2.020e-02,
#         2.798e-01,  1.150e-02, -1.510e-02,  1.037e-01,  4.000e-04,
#        -1.040e-02,  1.960e-02,  1.265e-01,  8.280e-02, -1.369e-01,
#         1.070e-01,  1.270e-01, -3.490e-02, -6.830e-02, -1.140e-02,
#         3.370e-02,  1.260e-02,  7.920e-02,  4.400e-02, -2.530e-02,
#         4.890e-02, -7.850e-02, -6.259e-01, -9.720e-02,  1.654e-01,
#        -5.780e-02, -4.370e-02,  4.090e-02, -1.820e-02, -1.891e-01,
#         2.770e-02, -1.460e-02, -5.310e-02,  4.260e-02,  4.900e-03,
#         4.000e-03,  1.423e-01, -9.750e-02, -3.500e-03,  9.630e-02,
#        -1.900e-03, -1.466e-01, -1.662e-01,  6.650e-02, -1.500e-01,
#        -1.267e-01,  2.670e-02, -1.560e-01, -1.442e-01,  1.515e-01,
#         2.420e-02, -6.080e-02,  9.180e-02, -2.407e-01, -4.110e-02,
#        -1.420e-02,  6.550e-02, -3.590e-02,  1.459e-01,  9.400e-02,
#         1.590e-02,  6.380e-02, -1.077e-01, -5.170e-02, -1.370e-02,
#         5.120e-02, -2.750e-02, -5.070e-02,  6.900e-03,  3.660e-02,
#        -1.529e-01, -1.813e-01,  3.390e-02, -8.510e-02, -5.400e-02,
#         1.180e-01,  1.039e-01,  6.190e-02, -2.350e-02, -1.150e-02,
#         1.648e-01,  9.360e-02, -5.000e-03, -9.790e-02, -5.890e-02,
#        -7.210e-02, -1.586e-01,  2.270e-02, -4.460e-02, -3.398e-01,
#        -2.840e-02, -2.507e-01,  4.510e-02, -1.226e-01,  8.000e-02,
#         2.365e-01,  7.560e-02, -8.530e-02,  1.157e-01,  2.780e-02,
#         7.100e-02, -1.314e-01, -4.630e-02,  4.270e-02, -5.050e-02,
#        -2.490e-02,  1.182e-01,  4.810e-02, -1.085e-01, -1.600e-02,
#         3.900e-03, -3.860e-02,  1.551e-01,  2.695e-01,  7.070e-02,
#        -8.420e-02,  1.167e-01,  8.450e-02, -1.040e-02,  2.060e-02,
#         4.690e-02,  5.700e-03,  8.970e-02,  7.230e-02,  2.220e-02,
#         7.270e-02,  6.420e-02, -2.350e-02, -2.160e-02, -6.010e-02,
#         5.370e-02, -2.842e-01, -1.047e-01,  1.733e-01,  2.100e-03,
#        -1.050e-02,  1.143e-01,  2.150e-02,  7.400e-03, -5.040e-02,
#        -4.900e-03,  1.190e-02, -2.700e-02,  1.450e-02,  9.670e-02,
#         9.030e-02,  3.145e-01,  1.222e-01,  9.850e-02,  2.126e-01,
#        -1.030e-01,  7.930e-02, -7.870e-02, -5.930e-02,  7.390e-02,
#        -6.960e-02, -8.180e-02,  3.200e-02, -1.808e-01,  4.770e-02,
#         8.250e-02, -1.270e-02,  1.445e-01, -6.050e-02, -5.130e-02,
#         9.450e-02, -1.030e-01,  4.750e-02,  9.820e-02,  2.402e-01,
#         8.600e-03, -2.410e-02, -3.320e-02,  4.300e-02, -4.170e-02,
#         1.990e-02, -5.280e-02, -6.300e-02,  3.470e-02,  5.800e-02,
#        -2.600e-02,  1.113e-01,  9.890e-02, -3.800e-03, -1.272e-01,
#        -9.790e-02,  4.500e-03,  6.100e-03, -3.980e-02, -8.500e-03,
#        -3.500e-03, -1.191e-01, -9.490e-02,  1.230e-02,  1.705e-01,
#        -2.065e-01,  5.500e-02,  4.530e-02,  4.240e-02, -5.780e-02,
#        -3.480e-02, -1.770e-02,  3.437e-01, -6.590e-02,  9.240e-02,
#        -1.122e-01, -1.588e-01,  1.068e-01, -3.029e-01,  1.800e-03,
#         3.170e-02,  1.857e-01,  3.600e-02,  8.290e-02,  2.240e-02,
#         9.340e-02, -4.750e-02,  1.719e-01,  1.500e-03,  4.849e-01,
#        -2.280e-02, -9.020e-02,  4.650e-02, -1.087e-01,  1.374e-01,
#         1.150e-02, -1.246e-01,  5.090e-02,  1.578e-01, -1.667e-01,
#        -3.400e-02,  4.690e-02,  5.680e-02,  1.599e-01, -3.915e-01,
#         3.560e-02,  2.870e-02, -2.275e-01, -1.378e-01, -2.650e-02,
#        -1.115e-01,  1.804e-01,  7.960e-02, -9.870e-02,  9.050e-02,
#         3.556e-01,  2.400e-02,  2.460e-02,  2.830e-02,  6.090e-02,
#        -2.270e-02, -4.690e-02, -5.350e-02,  4.400e-02,  1.021e-01,
#        -1.398e-01,  5.370e-02, -2.549e-01,  8.270e-02, -1.011e-01,
#         4.700e-03, -7.120e-02,  1.442e-01, -7.000e-02,  1.230e-02,
#         3.440e-02, -5.700e-02,  1.580e-02,  5.440e-02,  2.560e-02],
#       dtype=float32)

# %%
def sent_vectorizer(sent, model):
  sent_vec =[]
  numw = 0
  for w in sent:
    try:
      if numw == 0:
        sent_vec = model[w]
      else:
        sent_vec = np.add(sent_vec, model[w])
      numw+=1
    except:
      pass
  return np.asarray(sent_vec) / numw

# %%
df.iloc[:,0] = df.iloc[:,0].apply(clean_text)
print(df.iloc[:100,0])
# Out:
# <ipython-input-21-0330d7a0e727>:2: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, "lxml").text # HTML decoding
# 0     there are constants alpha and beta such that f...
# 1     the length of the segment between the points 2...
# 2     chewbacca has 20 pieces of cherry gum and 30 p...
# 3     for some constants a and b let f x left begin ...
# 4         calculate the sum 1 + 3 + 5 + cdots + 15 + 17
#                             ...
# 95    what is the largest value of x that satisfies ...
# 96    what is the sum of left dfrac 1 3 right + left...
# 97    on a map a 12centimeter length represents 72 k...
# 98    find the sum of all values of x such that 2 x2...
# 99    given that a 0 if f g a 8 where f x x2 + 8 and...
# Name: Problem , Length: 100, dtype: object

# %%
d = [];
for sent in df.iloc[:,0]:
  d.append(sent_vectorizer(sent, en_model))

# %%
x = pd.DataFrame(d)
x

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/FastText_levelsrecode.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -0.047231  0.015711 -0.071031 -0.007662  0.030991  0.059917
# 1           1 -0.098719  0.015418 -0.097384 -0.038516  0.043484  0.060653
# 2           2 -0.092993  0.026287 -0.107235 -0.050508  0.044317  0.051024
# 3           3 -0.074855  0.020305 -0.100434 -0.031188  0.016835  0.047498
# 4           4 -0.044288  0.022878 -0.035347 -0.002803  0.065113  0.079378
#
#           6         7         8  ...       290       291       292       293  \
# 0  0.004687 -0.046487  0.107146  ... -0.018673  0.030429 -0.016143  0.046663
# 1  0.018721 -0.041094  0.129638  ...  0.000181  0.017451 -0.012927  0.064079
# 2  0.017439 -0.049028  0.143363  ...  0.016668  0.016611 -0.022086  0.065026
# 3 -0.001790 -0.055538  0.132829  ... -0.001125  0.033835 -0.021322  0.058418
# 4  0.019056 -0.048419  0.116516  ... -0.013225  0.046087 -0.002287  0.054631
#
#         294       295       296       297       298       299
# 0  0.034890  0.028259 -0.000247 -0.030757  0.008817 -0.006377
# 1  0.031009  0.022566  0.020062 -0.025959 -0.026582  0.008801
# 2  0.024556  0.032230 -0.003800 -0.040938 -0.027009  0.004288
# 3  0.049020  0.035385 -0.014268 -0.031588 -0.023069  0.008638
# 4 -0.005369  0.021631  0.013978 -0.053094  0.023938  0.000747
#
# [5 rows x 301 columns]

# %%
from google.colab import files
x.to_csv('FastText_levelsrecode.csv') 
files.download('FastText_levelsrecode.csv')

# %%
y=df['Level ']

# %%
x.shape
# Out:
# (1744, 301)

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 301), (524, 301))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train) 
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.5750390647980984

# %% [markdown]
# **Model Building**

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.522131      0.522131         0.694888
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.474832       0.419847     0.419847        0.506472       0.377852

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     1.0000    1.0000    1.0000       361
#            2     1.0000    1.0000    1.0000       553
#            3     1.0000    1.0000    1.0000       306
#
#     accuracy                         1.0000      1220
#    macro avg     1.0000    1.0000    1.0000      1220
# weighted avg     1.0000    1.0000    1.0000      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6160    0.4904    0.5461       157
#            2     0.5157    0.7637    0.6156       237
#            3     0.6250    0.2308    0.3371       130
#
#     accuracy                         0.5496       524
#    macro avg     0.5856    0.4950    0.4996       524
# weighted avg     0.5729    0.5496    0.5257       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.522131      0.522131         0.694888
# 1   RandomForest        1.000000      1.000000         1.000000
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.474832       0.419847     0.419847        0.506472       0.377852
# 1        1.000000       0.549618     0.549618        0.572854       0.525698

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6667    0.5651    0.6117       361
#            2     0.5501    0.6456    0.5940       553
#            3     0.5962    0.5163    0.5534       306
#
#     accuracy                         0.5893      1220
#    macro avg     0.6043    0.5757    0.5864      1220
# weighted avg     0.5962    0.5893    0.5891      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5303    0.4459    0.4844       157
#            2     0.4698    0.5570    0.5097       237
#            3     0.3874    0.3308    0.3568       130
#
#     accuracy                         0.4676       524
#    macro avg     0.4625    0.4445    0.4503       524
# weighted avg     0.4675    0.4676    0.4642       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-39-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.637705      0.637705         0.635437
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.589344      0.589344         0.596151
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.636319       0.423664     0.423664        0.422651       0.422494
# 1        1.000000       0.570611     0.570611        0.583844       0.549607
# 2        0.589061       0.467557     0.467557        0.467460       0.464185

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9827    0.9446    0.9633       361
#            2     0.9398    0.9873    0.9630       553
#            3     0.9863    0.9412    0.9632       306
#
#     accuracy                         0.9631      1220
#    macro avg     0.9696    0.9577    0.9632      1220
# weighted avg     0.9641    0.9631    0.9631      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5390    0.5287    0.5338       157
#            2     0.5226    0.6329    0.5725       237
#            3     0.5060    0.3231    0.3944       130
#
#     accuracy                         0.5248       524
#    macro avg     0.5225    0.4949    0.5002       524
# weighted avg     0.5234    0.5248    0.5167       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-39-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.637705      0.637705         0.635437
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.589344      0.589344         0.596151
# 3            GBM        0.963115      0.963115         0.964142
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.636319       0.423664     0.423664        0.422651       0.422494
# 1        1.000000       0.570611     0.570611        0.583844       0.549607
# 2        0.589061       0.467557     0.467557        0.467460       0.464185
# 3        0.963118       0.524809     0.524809        0.523411       0.516709

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3569    0.6288    0.4554       361
#            2     0.5455    0.1302    0.2102       553
#            3     0.3628    0.5359    0.4327       306
#
#     accuracy                         0.3795      1220
#    macro avg     0.4217    0.4317    0.3661      1220
# weighted avg     0.4439    0.3795    0.3386      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3801    0.7070    0.4944       157
#            2     0.5349    0.0970    0.1643       237
#            3     0.3598    0.5231    0.4263       130
#
#     accuracy                         0.3855       524
#    macro avg     0.4249    0.4424    0.3617       524
# weighted avg     0.4451    0.3855    0.3282       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.522131      0.522131         0.694888
# 1   RandomForest        1.000000      1.000000         1.000000
# 2            SVM        0.379508      0.379508         0.443861
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.474832       0.419847     0.419847        0.506472       0.377852
# 1        1.000000       0.549618     0.549618        0.572854       0.525698
# 2        0.338565       0.385496     0.385496        0.445079       0.328215

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6837    0.5928    0.6350       361
#            2     0.6242    0.7360    0.6755       553
#            3     0.5882    0.4902    0.5348       306
#
#     accuracy                         0.6320      1220
#    macro avg     0.6321    0.6063    0.6151      1220
# weighted avg     0.6328    0.6320    0.6282      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5429    0.4841    0.5118       157
#            2     0.5036    0.5865    0.5419       237
#            3     0.4352    0.3615    0.3950       130
#
#     accuracy                         0.5000       524
#    macro avg     0.4939    0.4774    0.4829       524
# weighted avg     0.4984    0.5000    0.4964       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-39-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.637705      0.637705         0.635437
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.589344      0.589344         0.596151
# 3            GBM        0.963115      0.963115         0.964142
# 4            SVM        0.463115      0.463115         0.466353
# 5            KNN        0.631967      0.631967         0.632802
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.636319       0.423664     0.423664        0.422651       0.422494
# 1        1.000000       0.570611     0.570611        0.583844       0.549607
# 2        0.589061       0.467557     0.467557        0.467460       0.464185
# 3        0.963118       0.524809     0.524809        0.523411       0.516709
# 4        0.306276       0.459924     0.459924        0.430699       0.304096
# 5        0.628228       0.500000     0.500000        0.498400       0.496426

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4659    0.3601    0.4062       361
#            2     0.4398    0.1320    0.2031       553
#            3     0.3148    0.7974    0.4514       306
#
#     accuracy                         0.3664      1220
#    macro avg     0.4068    0.4298    0.3536      1220
# weighted avg     0.4162    0.3664    0.3255      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5000    0.3758    0.4291       157
#            2     0.4776    0.1350    0.2105       237
#            3     0.3156    0.8231    0.4563       130
#
#     accuracy                         0.3779       524
#    macro avg     0.4311    0.4446    0.3653       524
# weighted avg     0.4441    0.3779    0.3370       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-39-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.637705      0.637705         0.635437
# 1   RandomForest        1.000000      1.000000         1.000000
# 2       Adaboost        0.589344      0.589344         0.596151
# 3            GBM        0.963115      0.963115         0.964142
# 4            SVM        0.463115      0.463115         0.466353
# 5            KNN        0.631967      0.631967         0.632802
# 6            GNB        0.366393      0.366393         0.416176
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.636319       0.423664     0.423664        0.422651       0.422494
# 1        1.000000       0.570611     0.570611        0.583844       0.549607
# 2        0.589061       0.467557     0.467557        0.467460       0.464185
# 3        0.963118       0.524809     0.524809        0.523411       0.516709
# 4        0.306276       0.459924     0.459924        0.430699       0.304096
# 5        0.628228       0.500000     0.500000        0.498400       0.496426
# 6        0.325481       0.377863     0.377863        0.444135       0.336984
