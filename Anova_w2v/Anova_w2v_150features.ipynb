# %% [markdown]
# Anova_w2v_150features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np 
import pandas as pd
from sklearn import preprocessing 
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_W2v/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_W2v/w2v_withstopwordchangelevels_150_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.010392  0.475157  0.862862 -0.118716  0.418515 -0.728151
# 1           1 -0.510406  0.411782 -0.027414  1.332286 -0.742647 -0.437347
# 2           2  0.569645 -0.606454  0.660083 -0.912560  0.304170 -3.296995
# 3           3 -0.633456  0.620334 -0.486552 -0.687010 -0.106174  1.504521
# 4           4  0.433313 -0.343445  0.796141  1.268038  0.393716  0.297646
#
#           6         7         8  ...       140       141       142       143  \
# 0 -0.817971 -0.460686 -0.433980  ... -0.299832 -0.724903 -1.106845  1.118592
# 1 -0.633636 -1.081537 -0.205952  ... -0.640078 -0.656463 -0.594003  1.001050
# 2  1.135822  1.319312  0.847333  ...  0.317874 -1.597663  1.509677  0.213005
# 3  0.476870  0.293497 -0.268655  ... -0.372165  1.228908 -0.171695  0.242588
# 4  0.162916 -0.163843  0.819406  ...  1.073899  0.340677  2.756637  0.167587
#
#         144       145       146       147       148       149
# 0  1.040448 -0.532935 -1.228710 -0.697493  0.710486  0.471329
# 1 -0.568301 -0.769524  0.037346 -0.935630  0.944973  0.563732
# 2  0.816211 -1.004020 -1.642769  0.065312 -2.326596  1.080970
# 3 -1.549784  0.777835  0.136197 -0.019550 -0.331169 -1.020494
# 4 -0.754740 -1.393842 -2.024802  0.092178 -0.095505 -0.526746
#
# [5 rows x 151 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.010392  0.475157  0.862862 -0.118716  0.418515 -0.728151 -0.817971
# 1 -0.510406  0.411782 -0.027414  1.332286 -0.742647 -0.437347 -0.633636
# 2  0.569645 -0.606454  0.660083 -0.912560  0.304170 -3.296995  1.135822
# 3 -0.633456  0.620334 -0.486552 -0.687010 -0.106174  1.504521  0.476870
# 4  0.433313 -0.343445  0.796141  1.268038  0.393716  0.297646  0.162916
#
#           7         8         9  ...       140       141       142       143  \
# 0 -0.460686 -0.433980 -0.394739  ... -0.299832 -0.724903 -1.106845  1.118592
# 1 -1.081537 -0.205952  0.209997  ... -0.640078 -0.656463 -0.594003  1.001050
# 2  1.319312  0.847333 -1.101063  ...  0.317874 -1.597663  1.509677  0.213005
# 3  0.293497 -0.268655  1.031454  ... -0.372165  1.228908 -0.171695  0.242588
# 4 -0.163843  0.819406 -0.189012  ...  1.073899  0.340677  2.756637  0.167587
#
#         144       145       146       147       148       149
# 0  1.040448 -0.532935 -1.228710 -0.697493  0.710486  0.471329
# 1 -0.568301 -0.769524  0.037346 -0.935630  0.944973  0.563732
# 2  0.816211 -1.004020 -1.642769  0.065312 -2.326596  1.080970
# 3 -1.549784  0.777835  0.136197 -0.019550 -0.331169 -1.020494
# 4 -0.754740 -1.393842 -2.024802  0.092178 -0.095505 -0.526746
#
# [5 rows x 150 columns]

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 150), (524, 150))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.372946706248233

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-20-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.370492      0.370492          0.56469
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.329022       0.280534     0.280534        0.357431       0.228066

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     1.0000    0.9972    0.9986       361
#            2     1.0000    1.0000    1.0000       553
#            3     0.9967    1.0000    0.9984       306
#
#     accuracy                         0.9992      1220
#    macro avg     0.9989    0.9991    0.9990      1220
# weighted avg     0.9992    0.9992    0.9992      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2703    0.1274    0.1732       157
#            2     0.4668    0.8017    0.5901       237
#            3     0.3256    0.1077    0.1618       130
#
#     accuracy                         0.4275       524
#    macro avg     0.3542    0.3456    0.3084       524
# weighted avg     0.3729    0.4275    0.3589       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-20-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.370492      0.370492         0.564690
# 1   RandomForest        0.999180      0.999180         0.999183
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.329022       0.280534     0.280534        0.357431       0.228066
# 1        0.999180       0.427481     0.427481        0.372895       0.358915

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5735    0.3352    0.4231       361
#            2     0.5343    0.8174    0.6462       553
#            3     0.6687    0.3562    0.4648       306
#
#     accuracy                         0.5590      1220
#    macro avg     0.5922    0.5029    0.5114      1220
# weighted avg     0.5796    0.5590    0.5347      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2680    0.1656    0.2047       157
#            2     0.4399    0.6793    0.5340       237
#            3     0.2459    0.1154    0.1571       130
#
#     accuracy                         0.3855       524
#    macro avg     0.3179    0.3201    0.2986       524
# weighted avg     0.3403    0.3855    0.3418       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.505738      0.505738         0.628773
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.559016      0.559016         0.579591
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.409286       0.416031     0.416031        0.328204       0.309256
# 1        0.999180       0.435115     0.435115        0.394000       0.369242
# 2        0.534673       0.385496     0.385496        0.340274       0.341828

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9789    0.8975    0.9364       361
#            2     0.8828    0.9946    0.9354       553
#            3     0.9925    0.8627    0.9231       306
#
#     accuracy                         0.9328      1220
#    macro avg     0.9514    0.9183    0.9316      1220
# weighted avg     0.9387    0.9328    0.9326      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3107    0.2038    0.2462       157
#            2     0.4714    0.7300    0.5728       237
#            3     0.3148    0.1308    0.1848       130
#
#     accuracy                         0.4237       524
#    macro avg     0.3656    0.3548    0.3346       524
# weighted avg     0.3844    0.4237    0.3787       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.505738      0.505738         0.628773
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.559016      0.559016         0.579591
# 3            GBM        0.932787      0.932787         0.938743
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.409286       0.416031     0.416031        0.328204       0.309256
# 1        0.999180       0.435115     0.435115        0.394000       0.369242
# 2        0.534673       0.385496     0.385496        0.340274       0.341828
# 3        0.932598       0.423664     0.423664        0.384393       0.378689

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3778    0.3684    0.3731       361
#            2     0.5548    0.4575    0.5015       553
#            3     0.3422    0.4608    0.3928       306
#
#     accuracy                         0.4320      1220
#    macro avg     0.4250    0.4289    0.4224      1220
# weighted avg     0.4491    0.4320    0.4362      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3141    0.3121    0.3131       157
#            2     0.4712    0.4135    0.4404       237
#            3     0.2812    0.3462    0.3103       130
#
#     accuracy                         0.3664       524
#    macro avg     0.3555    0.3573    0.3546       524
# weighted avg     0.3770    0.3664    0.3700       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-20-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.370492      0.370492         0.564690
# 1   RandomForest        0.999180      0.999180         0.999183
# 2            SVM        0.431967      0.431967         0.449133
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.329022       0.280534     0.280534        0.357431       0.228066
# 1        0.999180       0.427481     0.427481        0.372895       0.358915
# 2        0.436217       0.366412     0.366412        0.376985       0.370015

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4403    0.4598    0.4499       361
#            2     0.5688    0.6727    0.6164       553
#            3     0.5185    0.3203    0.3960       306
#
#     accuracy                         0.5213      1220
#    macro avg     0.5092    0.4843    0.4874      1220
# weighted avg     0.5182    0.5213    0.5118      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2922    0.2866    0.2894       157
#            2     0.4793    0.5865    0.5275       237
#            3     0.2375    0.1462    0.1810       130
#
#     accuracy                         0.3874       524
#    macro avg     0.3363    0.3398    0.3326       524
# weighted avg     0.3633    0.3874    0.3702       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.505738      0.505738         0.628773
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.559016      0.559016         0.579591
# 3            GBM        0.932787      0.932787         0.938743
# 4            SVM        0.453279      0.453279         0.205462
# 5            KNN        0.521311      0.521311         0.518174
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.409286       0.416031     0.416031        0.328204       0.309256
# 1        0.999180       0.435115     0.435115        0.394000       0.369242
# 2        0.534673       0.385496     0.385496        0.340274       0.341828
# 3        0.932598       0.423664     0.423664        0.384393       0.378689
# 4        0.282756       0.452290     0.452290        0.204566       0.281716
# 5        0.511833       0.387405     0.387405        0.363260       0.370188

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4239    0.1080    0.1722       361
#            2     0.4624    0.7559    0.5738       553
#            3     0.3214    0.2353    0.2717       306
#
#     accuracy                         0.4336      1220
#    macro avg     0.4026    0.3664    0.3392      1220
# weighted avg     0.4156    0.4336    0.3792      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2791    0.0764    0.1200       157
#            2     0.4405    0.7342    0.5506       237
#            3     0.1860    0.1231    0.1481       130
#
#     accuracy                         0.3855       524
#    macro avg     0.3019    0.3112    0.2729       524
# weighted avg     0.3290    0.3855    0.3218       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.505738      0.505738         0.628773
# 1   RandomForest        0.999180      0.999180         0.999183
# 2       Adaboost        0.559016      0.559016         0.579591
# 3            GBM        0.932787      0.932787         0.938743
# 4            SVM        0.453279      0.453279         0.205462
# 5            KNN        0.521311      0.521311         0.518174
# 6            GNB        0.433607      0.433607         0.415648
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.409286       0.416031     0.416031        0.328204       0.309256
# 1        0.999180       0.435115     0.435115        0.394000       0.369242
# 2        0.534673       0.385496     0.385496        0.340274       0.341828
# 3        0.932598       0.423664     0.423664        0.384393       0.378689
# 4        0.282756       0.452290     0.452290        0.204566       0.281716
# 5        0.511833       0.387405     0.387405        0.363260       0.370188
# 6        0.379180       0.385496     0.385496        0.329008       0.321754
