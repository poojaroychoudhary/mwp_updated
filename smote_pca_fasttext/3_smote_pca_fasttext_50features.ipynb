# %% [markdown]
# Smote_pca_features

# %%
from google.colab import drive
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import numpy as np 
from imblearn.over_sampling import SMOTE 
from sklearn.model_selection import KFold
from sklearn import metrics
from tensorflow.keras.utils import to_categorical
from sklearn.linear_model import LinearRegression 
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn import svm
from sklearn import model_selection
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import MultiLabelBinarizer

# %% [markdown]
# **Models**

# %%
def Decision_tree_classifier(X_train, y_train, X_test, y_test):
  # Create Decision Tree classifer object
  clf = DecisionTreeClassifier(class_weight = "balanced")

  # Train Decision Tree Classifer
  clf = clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)

  print("Decision Tree Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("Decision Tree F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def GNB_classifier (X_train, y_train, X_test, y_test):
  #Create a Gaussian Classifier
  gnb = GaussianNB()

  #Train the model using the training sets
  gnb.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = gnb.predict(X_test)

  print("Gaussian Naive Bayes Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("Gaussian Naive Bayes F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def KNN_classifier (X_train, y_train, X_test, y_test):
  #Create KNN Classifier
  knn = KNeighborsClassifier(n_neighbors=5)

  #Train the model using the training sets
  knn.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = knn.predict(X_test)

  print("KNN Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("KNN F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def svm_classifier (X_train, y_train, X_test, y_test):
  #Create a Support Vector Machine Classifier
  clf = svm.SVC(kernel='linear', class_weight = "balanced") # Linear Kernel

  #Train the model using the training sets
  clf.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = clf.predict(X_test)

  print("SVM Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("SVM F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def random_forest_classifier (X_train, y_train, X_test, y_test):
  #Create a Gaussian Classifier
  clf=RandomForestClassifier(n_estimators=100, class_weight = "balanced")

  #Train the model using the training sets y_pred=clf.predict(X_test)
  clf.fit(X_train,y_train)

  #Predict the response for test dataset
  y_pred=clf.predict(X_test)
  print("RF Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("RF F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def ada_boost_classifier (X_train, y_train, X_test, y_test):
  # Create adaboost classifer object
  abc = AdaBoostClassifier(n_estimators=50,
                          learning_rate=1)
  # Train Adaboost Classifer
  model = abc.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = model.predict(X_test)

  print("Ada-Boost Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("Ada-Boost F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def gradient_boost_classifier (X_train, y_train, X_test, y_test):
  # Create adaboost classifer object
  gbc = GradientBoostingClassifier(n_estimators=50,
                          learning_rate=1)
  # Train Adaboost Classifer
  model = gbc.fit(X_train, y_train)

  #Predict the response for test dataset
  y_pred = model.predict(X_test)

  print("Gradient-Boost Accuracy:",metrics.accuracy_score(y_test, y_pred))
  print("Gradient-Boost F1 Score:",metrics.f1_score(y_test, y_pred, average='weighted'))

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/smote_pca_fasttext/data.csv"
df3 = pd.read_csv(path)
df3.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df3.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df3.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df3['Level '] = pd.cut(df3["Level "],bins,labels = group_names)

# %%
df3.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df3['Level '] = df3['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df3.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/smote_pca_fasttext/fasttext_withstopwordchangelevels_50_features.csv"
df2 = pd.read_csv(path)
df2.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -6.479078  1.651257  0.896314  3.535852  2.867422  1.560191
# 1           1 -5.452967  2.308225 -6.763821  4.569993  0.856911 -0.518583
# 2           2 -8.162915  0.634287 -1.216198 -1.509451 -1.288995  3.823911
# 3           3 -6.632410  3.739571 -1.834406  0.031421  0.661350 -1.142883
# 4           4 -1.823112  2.290021  3.397779  5.673997 -2.436430 -2.122263
#
#           6         7         8  ...            40        41            42  \
# 0 -0.960358 -4.078380  0.547516  ...  6.695309e-07  0.000003  9.046899e-08
# 1 -2.731985 -0.432451  0.335011  ...  3.345125e-06  0.000006  8.161220e-07
# 2 -1.172312  0.457859 -2.033172  ... -1.055074e-05 -0.000003  4.170370e-06
# 3 -3.133973 -1.202540 -2.633310  ...  7.818613e-06  0.000005  2.075646e-06
# 4 -0.676238  7.185288 -0.713091  ... -2.626606e-06 -0.000004 -4.484433e-06
#
#              43            44        45            46            47  \
# 0 -4.097595e-07 -4.108224e-07 -0.000002  1.357596e-06  1.974855e-07
# 1 -1.593020e-07  3.119997e-06 -0.000002 -8.159281e-07 -4.400613e-07
# 2  6.558600e-06  1.725653e-06 -0.000003 -1.960362e-06 -3.647499e-06
# 3  2.829128e-06  1.148339e-06  0.000002 -1.569741e-06 -3.400200e-07
# 4  3.324942e-06 -1.525081e-06  0.000002  1.449589e-06 -1.708901e-06
#
#              48            49
# 0 -1.126599e-06 -3.217740e-06
# 1  3.657790e-06  6.288601e-07
# 2  1.803280e-07  6.976526e-07
# 3  2.084161e-06  4.895014e-07
# 4  4.329716e-07 -1.685343e-06
#
# [5 rows x 51 columns]

# %%
df2.drop(df2.columns[[0]], axis=1, inplace=True)
df2.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -6.479078  1.651257  0.896314  3.535852  2.867422  1.560191 -0.960358
# 1 -5.452967  2.308225 -6.763821  4.569993  0.856911 -0.518583 -2.731985
# 2 -8.162915  0.634287 -1.216198 -1.509451 -1.288995  3.823911 -1.172312
# 3 -6.632410  3.739571 -1.834406  0.031421  0.661350 -1.142883 -3.133973
# 4 -1.823112  2.290021  3.397779  5.673997 -2.436430 -2.122263 -0.676238
#
#           7         8         9  ...            40        41            42  \
# 0 -4.078380  0.547516 -1.175984  ...  6.695309e-07  0.000003  9.046899e-08
# 1 -0.432451  0.335011 -1.138042  ...  3.345125e-06  0.000006  8.161220e-07
# 2  0.457859 -2.033172 -0.040681  ... -1.055074e-05 -0.000003  4.170370e-06
# 3 -1.202540 -2.633310  4.376703  ...  7.818613e-06  0.000005  2.075646e-06
# 4  7.185288 -0.713091  1.961139  ... -2.626606e-06 -0.000004 -4.484433e-06
#
#              43            44        45            46            47  \
# 0 -4.097595e-07 -4.108224e-07 -0.000002  1.357596e-06  1.974855e-07
# 1 -1.593020e-07  3.119997e-06 -0.000002 -8.159281e-07 -4.400613e-07
# 2  6.558600e-06  1.725653e-06 -0.000003 -1.960362e-06 -3.647499e-06
# 3  2.829128e-06  1.148339e-06  0.000002 -1.569741e-06 -3.400200e-07
# 4  3.324942e-06 -1.525081e-06  0.000002  1.449589e-06 -1.708901e-06
#
#              48            49
# 0 -1.126599e-06 -3.217740e-06
# 1  3.657790e-06  6.288601e-07
# 2  1.803280e-07  6.976526e-07
# 3  2.084161e-06  4.895014e-07
# 4  4.329716e-07 -1.685343e-06
#
# [5 rows x 50 columns]

# %%
df2['Level'] = df3['Level '].values
df2.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -6.479078  1.651257  0.896314  3.535852  2.867422  1.560191 -0.960358
# 1 -5.452967  2.308225 -6.763821  4.569993  0.856911 -0.518583 -2.731985
# 2 -8.162915  0.634287 -1.216198 -1.509451 -1.288995  3.823911 -1.172312
# 3 -6.632410  3.739571 -1.834406  0.031421  0.661350 -1.142883 -3.133973
# 4 -1.823112  2.290021  3.397779  5.673997 -2.436430 -2.122263 -0.676238
#
#           7         8         9  ...        41            42            43  \
# 0 -4.078380  0.547516 -1.175984  ...  0.000003  9.046899e-08 -4.097595e-07
# 1 -0.432451  0.335011 -1.138042  ...  0.000006  8.161220e-07 -1.593020e-07
# 2  0.457859 -2.033172 -0.040681  ... -0.000003  4.170370e-06  6.558600e-06
# 3 -1.202540 -2.633310  4.376703  ...  0.000005  2.075646e-06  2.829128e-06
# 4  7.185288 -0.713091  1.961139  ... -0.000004 -4.484433e-06  3.324942e-06
#
#              44        45            46            47            48  \
# 0 -4.108224e-07 -0.000002  1.357596e-06  1.974855e-07 -1.126599e-06
# 1  3.119997e-06 -0.000002 -8.159281e-07 -4.400613e-07  3.657790e-06
# 2  1.725653e-06 -0.000003 -1.960362e-06 -3.647499e-06  1.803280e-07
# 3  1.148339e-06  0.000002 -1.569741e-06 -3.400200e-07  2.084161e-06
# 4 -1.525081e-06  0.000002  1.449589e-06 -1.708901e-06  4.329716e-07
#
#              49  Level
# 0 -3.217740e-06      3
# 1  6.288601e-07      3
# 2  6.976526e-07      3
# 3  4.895014e-07      3
# 4 -1.685343e-06      1
#
# [5 rows x 51 columns]

# %%
 #Data Shuffling
df2 = df2.sample(frac = 1) #frac denotes the fraction of samples to be returned. 

 
#train-test split
trdata = df2.sample(frac=0.7, random_state=25) #Training data = 70%
tsdata = df2.drop(trdata.index) #Testing data = 30%
X_train = trdata.iloc[:,:-1]
y_train = trdata.iloc[:,-1]
X_test = tsdata.iloc[:,:-1]
y_test = tsdata.iloc[:,-1]

#SMOTE
sm = SMOTE()
X_train, y_train = sm.fit_resample(X_train, y_train.ravel())

# %%
#Model Calling
Decision_tree_classifier(X_train, y_train, X_test, y_test)
GNB_classifier(X_train, y_train, X_test, y_test)
KNN_classifier(X_train, y_train, X_test, y_test) 
svm_classifier(X_train, y_train, X_test, y_test)
random_forest_classifier(X_train, y_train, X_test, y_test)
ada_boost_classifier(X_train, y_train, X_test, y_test)
gradient_boost_classifier(X_train, y_train, X_test, y_test)
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Decision Tree Accuracy: 0.3384321223709369
# Decision Tree F1 Score: 0.3428109900253369
# Gaussian Naive Bayes Accuracy: 0.3173996175908222
# Gaussian Naive Bayes F1 Score: 0.32116972040529385
# KNN Accuracy: 0.3441682600382409
# KNN F1 Score: 0.3459309075326494
# SVM Accuracy: 0.35564053537284895
# SVM F1 Score: 0.36023722451909346
# RF Accuracy: 0.4072657743785851
# RF F1 Score: 0.39709970812690903
# Ada-Boost Accuracy: 0.34990439770554493
# Ada-Boost F1 Score: 0.35448195618504386
# Gradient-Boost Accuracy: 0.35564053537284895
# Gradient-Boost F1 Score: 0.35538499229698345
# Perceptron F1 score: 0.3277240850691235
