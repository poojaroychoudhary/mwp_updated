# %% [markdown]
# 3 levels

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Reshape, Dense, Lambda
from tensorflow.keras.losses import MeanSquaredError
from sklearn.neural_network import MLPRegressor

# %%
import math
import pandas as pd
import tensorflow as tf
#import kerastuner.tuners as kt
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError

# %%
path = "/content/drive/MyDrive/newpro/threeclass_problem/bert_changedlevels.csv"
dataset = pd.read_csv(path)
dataset.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.251582  0.065441  0.036327 -0.683447 -0.864267  0.043688
# 1           1  0.307343  0.046227  0.070979 -0.689943 -0.421657 -0.045189
# 2           2  0.330305  0.214742  0.517233 -0.529509 -0.374165 -0.236629
# 3           3  0.266967  0.254776  0.249469 -0.518748 -0.460016 -0.099519
# 4           4  0.221523  0.013097 -0.097723 -1.067212 -0.829449  0.143097
#
#           6         7         8  ...       759       760       761       762  \
# 0 -0.182814 -0.056845  0.180367  ...  0.057088  0.038299  0.289821 -0.283759
# 1  0.146107 -0.190608  0.162453  ...  0.373472  0.056404  0.079221 -0.368649
# 2  0.780357 -0.248850  0.348099  ...  0.052816 -0.340460  0.361714 -0.405706
# 3  0.359582  0.087548  0.356397  ...  0.190572  0.242963  0.207410 -0.466586
# 4 -0.051330 -0.085799  0.035921  ...  0.261153 -0.027681  0.528556 -0.489401
#
# ...

# %%
def PreProcessing(dataset):
  #Remove First row (Indexing from Excel)
  dataset = dataset.iloc[:, 1:] 
  
  #Shuffling
  dataset = dataset.sample(frac = 1) #frac denotes the fraction of samples to be returned. 

  # distributing the dataset into two components X and Y
  X = dataset.iloc[:, 0:-1].values
  y = dataset.iloc[:, -1].values

  #Scaling (Standardization)
  sc = StandardScaler()
  X = sc.fit_transform(X)

  print(X.shape)
  print(y.shape)
  return X, y

# %%
X, y = PreProcessing(dataset)
# Out:
# (1744, 768)
# (1744,)

# %%
autoencoder = MLPRegressor(alpha = 1e-15,hidden_layer_sizes=(1744,3488,1744,20,1744,3488,765)
                          , random_state=1,max_iter=20000)
autoencoder.fit(X,X)
# Out:
# MLPRegressor(alpha=1e-15,
#              hidden_layer_sizes=(1744, 3488, 1744, 20, 1744, 3488, 765),
#              max_iter=20000, random_state=1)

# %%
L= autoencoder.coefs_

# %%
biases = autoencoder.intercepts_

# %%
i = 0
for l in L:
    print(l.shape)  
    if i==3: 
      print(l)
    i = i+1
# Out:
# (768, 1744)
# (1744, 3488)
# (3488, 1744)
# (1744, 20)
# [[-0.04076597 -0.01116534  0.04961898 ...  0.01483423  0.03669986
#    0.00834465]
#  [ 0.03426245  0.0440108   0.04939355 ...  0.01997288 -0.00322427
#   -0.02022878]
#  [ 0.03064138  0.04332588  0.01874646 ... -0.01309117  0.00766625
#    0.01792521]
#  ...
#  [-0.0272118   0.00085499  0.01170215 ... -0.03232702 -0.006039
#    0.00588916]
#  [ 0.04424278  0.04642968  0.03074329 ...  0.03124038  0.00284434
#   -0.04422185]
#  [-0.05922934  0.02476701  0.04081377 ... -0.06261806  0.00196117
#    0.03760712]]
# (20, 1744)
# (1744, 3488)
# (3488, 765)
# (765, 768)

# %%
L[3].shape
# Out:
# (1744, 20)

# %%
df1 = pd.DataFrame(L[3])
df1
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.040766 -0.011165  0.049619 -0.036195 -0.001590 -0.036157 -0.055003
# 1     0.034262  0.044011  0.049394  0.044758  0.021972 -0.010830  0.021829
# 2     0.030641  0.043326  0.018746  0.046257 -0.005205  0.046819 -0.032563
# 3     0.039085  0.026694  0.036269  0.004421 -0.020205  0.010260 -0.031908
# 4     0.052076  0.061837 -0.030563 -0.049211  0.019215 -0.017553 -0.051692
# ...        ...       ...       ...       ...       ...       ...       ...
# 1739  0.028844 -0.030966 -0.018719  0.036808  0.028445 -0.000807  0.018291
# 1740  0.001460 -0.023375  0.048252  0.036161 -0.020807  0.021246 -0.010920
# 1741 -0.027212  0.000855  0.011702 -0.014936  0.025860  0.019171  0.039156
# 1742  0.044243  0.046430  0.030743 -0.061707 -0.037936  0.016847  0.027890
# 1743 -0.059229  0.024767  0.040814 -0.017914 -0.035692 -0.009650 -0.042676
#
# ...

# %%
df1.to_csv('bert_2autoencode_withstopwordchangelevels_20_features.csv') 
files.download('bert_2autoencode_withstopwordchangelevels_20_features.csv')

# %% [markdown]
# **Repeat for all word embeddings**

# %%
#FastText
path = "/content/drive/MyDrive/newpro/threeclass_problem/fasttext_changedlevels.csv"
dataset = pd.read_csv(path)
X, y = PreProcessing(dataset)
autoencoder = MLPRegressor(alpha = 1e-15,hidden_layer_sizes=(1744,3488,1744,20,1744,3488,300)
                          , random_state=1,max_iter=10000)
autoencoder.fit(X,X) 
L= autoencoder.coefs_
biases = autoencoder.intercepts_ 
df1 = pd.DataFrame(L[3]) 
df1.to_csv('fasttext_2autoencode_withstopwordchangelevels_20_features.csv') 
files.download('fasttext_2autoencode_withstopwordchangelevels_20_features.csv')
# Out:
# (1744, 300)
# (1744,)

# %%
#Glove
path = "/content/drive/MyDrive/newpro/threeclass_problem/glove_changedlevels.csv"  
dataset = pd.read_csv(path) 
X, y = PreProcessing(dataset)
autoencoder = MLPRegressor(alpha = 1e-15,hidden_layer_sizes=(1744,3488,1744,20,1744,3488,300)
                          , random_state=1,max_iter=20000)
autoencoder.fit(X,X)
L= autoencoder.coefs_
biases = autoencoder.intercepts_ 
df1 = pd.DataFrame(L[3])
df1.to_csv('glove_2autoencode_withstopwordchangelevels_20_features.csv') 
files.download('glove_2autoencode_withstopwordchangelevels_20_features.csv')
# Out:
# (1744, 300)
# (1744,)

# %%
#TFIDF
path = "/content/drive/MyDrive/newpro/threeclass_problem/tfidf_changedlevels.csv" 
dataset = pd.read_csv(path)
X, y = PreProcessing(dataset) 
autoencoder = MLPRegressor(alpha = 1e-15,hidden_layer_sizes=(1744,3488,1744,20,1744,3488,3500)
                          , random_state=1,max_iter=10000)
autoencoder.fit(X,X)
L= autoencoder.coefs_
biases = autoencoder.intercepts_
df1 = pd.DataFrame(L[3])
df1.to_csv('tfidf_2autoencode_withstopwordchangelevels_20_features.csv') 
files.download('tfidf_2autoencode_withstopwordchangelevels_20_features.csv')
# Out:
# (1744, 3604)
# (1744,)

# %%
#Word2Vec
path = "/content/drive/MyDrive/newpro/threeclass_problem/w2v_changedlevels.csv" 
dataset = pd.read_csv(path)
X, y = PreProcessing(dataset)
autoencoder = MLPRegressor(alpha = 1e-15,hidden_layer_sizes=(1744,3488,1744,20,1744,3488,300)
                          , random_state=1,max_iter=20000)
autoencoder.fit(X,X)
L= autoencoder.coefs_
biases = autoencoder.intercepts_
df1 = pd.DataFrame(L[3])
df1.to_csv('w2v_2autoencode_withstopwordchangelevels_20_features.csv') 
files.download('w2v_2autoencode_withstopwordchangelevels_20_features.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:693: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
