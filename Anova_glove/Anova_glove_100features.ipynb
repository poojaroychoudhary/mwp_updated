# %% [markdown]
# Anova_glove_100features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np 
import pandas as pd
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_Glove/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_Glove/glove_withstopwordchangelevels_100_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -0.580685  0.371574 -0.391762  0.809298  0.646726 -0.862823
# 1           1 -1.042461 -2.066468 -0.789155 -0.824249  1.615863 -0.375772
# 2           2 -1.792921  1.154722  1.614127 -0.218415  0.820524  0.426222
# 3           3 -0.451693 -0.507893 -0.850427 -1.418923  1.120592  1.139462
# 4           4  0.013113 -0.657587 -0.959673  0.935290  0.443002  0.481516
#
#           6         7         8  ...        90        91        92        93  \
# 0 -0.553467  1.407969 -0.999407  ...  0.150714 -0.203825  2.499038  0.489808
# 1 -0.323857  0.992652 -0.779970  ...  2.111509  1.006012 -1.769825 -0.210532
# 2  2.028454  2.530408 -1.206933  ... -1.911313  1.092629 -2.317413  0.467989
# 3  1.473503  2.048871 -0.712543  ...  1.285076  0.744136 -1.205626 -0.663380
# 4 -0.355975  0.341538 -0.004934  ...  0.340065 -0.450416 -0.333113 -0.335696
#
#          94        95        96        97        98        99
# 0 -0.842514 -0.168322  1.039558  0.115144 -0.475154 -0.202550
# 1  2.521209  0.619154 -0.525751  0.270385 -1.616480 -1.498784
# 2 -0.780457 -2.067063 -0.166924  0.391798  0.916318  1.813036
# 3  0.735662 -0.919880 -1.113695 -0.107428 -0.140057 -0.607724
# 4  0.678209  0.303339 -0.248480 -0.700426  0.113338  0.404674
#
# [5 rows x 101 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.580685  0.371574 -0.391762  0.809298  0.646726 -0.862823 -0.553467
# 1 -1.042461 -2.066468 -0.789155 -0.824249  1.615863 -0.375772 -0.323857
# 2 -1.792921  1.154722  1.614127 -0.218415  0.820524  0.426222  2.028454
# 3 -0.451693 -0.507893 -0.850427 -1.418923  1.120592  1.139462  1.473503
# 4  0.013113 -0.657587 -0.959673  0.935290  0.443002  0.481516 -0.355975
#
#           7         8         9  ...        90        91        92        93  \
# 0  1.407969 -0.999407  0.843822  ...  0.150714 -0.203825  2.499038  0.489808
# 1  0.992652 -0.779970 -0.110640  ...  2.111509  1.006012 -1.769825 -0.210532
# 2  2.530408 -1.206933  0.329011  ... -1.911313  1.092629 -2.317413  0.467989
# 3  2.048871 -0.712543 -1.412507  ...  1.285076  0.744136 -1.205626 -0.663380
# 4  0.341538 -0.004934  0.043467  ...  0.340065 -0.450416 -0.333113 -0.335696
#
#          94        95        96        97        98        99
# 0 -0.842514 -0.168322  1.039558  0.115144 -0.475154 -0.202550
# 1  2.521209  0.619154 -0.525751  0.270385 -1.616480 -1.498784
# 2 -0.780457 -2.067063 -0.166924  0.391798  0.916318  1.813036
# 3  0.735662 -0.919880 -1.113695 -0.107428 -0.140057 -0.607724
# 4  0.678209  0.303339 -0.248480 -0.700426  0.113338  0.404674
#
# [5 rows x 100 columns]

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 100), (524, 100))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.3365873132124222

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.472951      0.472951         0.587873
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.469827       0.290076     0.290076        0.337359       0.272703

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9621    0.9834    0.9726       361
#            2     0.9815    0.9602    0.9707       553
#            3     0.9548    0.9673    0.9610       306
#
#     accuracy                         0.9689      1220
#    macro avg     0.9661    0.9703    0.9681      1220
# weighted avg     0.9691    0.9689    0.9689      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.1970    0.0828    0.1166       157
#            2     0.4439    0.7848    0.5671       237
#            3     0.2308    0.0692    0.1065       130
#
#     accuracy                         0.3969       524
#    macro avg     0.2906    0.3123    0.2634       524
# weighted avg     0.3170    0.3969    0.3178       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.472951      0.472951         0.587873
# 1   RandomForest        0.968852      0.968852         0.969068
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.469827       0.290076     0.290076        0.337359       0.272703
# 1        0.968862       0.396947     0.396947        0.317046       0.317839

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5428    0.4044    0.4635       361
#            2     0.5587    0.7577    0.6431       553
#            3     0.5970    0.3922    0.4734       306
#
#     accuracy                         0.5615      1220
#    macro avg     0.5661    0.5181    0.5267      1220
# weighted avg     0.5636    0.5615    0.5474      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2828    0.1783    0.2187       157
#            2     0.4622    0.6709    0.5473       237
#            3     0.2716    0.1692    0.2085       130
#
#     accuracy                         0.3989       524
#    macro avg     0.3389    0.3395    0.3249       524
# weighted avg     0.3612    0.3989    0.3648       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-22-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.539344      0.539344         0.614836
# 1   RandomForest        0.969672      0.969672         0.970237
# 2       Adaboost        0.561475      0.561475         0.563576
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.466560       0.425573     0.425573        0.320646       0.348863
# 1        0.969692       0.391221     0.391221        0.307093       0.318843
# 2        0.547397       0.398855     0.398855        0.361176       0.364829

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9789    0.9003    0.9380       361
#            2     0.8736    0.9873    0.9270       553
#            3     0.9772    0.8399    0.9033       306
#
#     accuracy                         0.9246      1220
#    macro avg     0.9432    0.9092    0.9228      1220
# weighted avg     0.9307    0.9246    0.9243      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2857    0.1783    0.2196       157
#            2     0.4624    0.7004    0.5570       237
#            3     0.2836    0.1462    0.1929       130
#
#     accuracy                         0.4065       524
#    macro avg     0.3439    0.3416    0.3232       524
# weighted avg     0.3651    0.4065    0.3656       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-22-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.539344      0.539344         0.614836
# 1   RandomForest        0.969672      0.969672         0.970237
# 2       Adaboost        0.561475      0.561475         0.563576
# 3            GBM        0.924590      0.924590         0.930745
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.466560       0.425573     0.425573        0.320646       0.348863
# 1        0.969692       0.391221     0.391221        0.307093       0.318843
# 2        0.547397       0.398855     0.398855        0.361176       0.364829
# 3        0.924303       0.406489     0.406489        0.365096       0.365601

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.4353    0.5125    0.4707       361
#            2     0.6220    0.4611    0.5296       553
#            3     0.4104    0.5163    0.4573       306
#
#     accuracy                         0.4902      1220
#    macro avg     0.4892    0.4966    0.4859      1220
# weighted avg     0.5137    0.4902    0.4940      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2690    0.2930    0.2805       157
#            2     0.4398    0.3544    0.3925       237
#            3     0.2284    0.2846    0.2534       130
#
#     accuracy                         0.3187       524
#    macro avg     0.3124    0.3107    0.3088       524
# weighted avg     0.3362    0.3187    0.3244       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-19-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.472951      0.472951         0.587873
# 1   RandomForest        0.968852      0.968852         0.969068
# 2            SVM        0.490164      0.490164         0.513655
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.469827       0.290076     0.290076        0.337359       0.272703
# 1        0.968862       0.396947     0.396947        0.317046       0.317839
# 2        0.494048       0.318702     0.318702        0.336175       0.324446

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5075    0.4709    0.4885       361
#            2     0.5724    0.7649    0.6548       553
#            3     0.5205    0.2484    0.3363       306
#
#     accuracy                         0.5484      1220
#    macro avg     0.5335    0.4947    0.4932      1220
# weighted avg     0.5402    0.5484    0.5257      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2880    0.2293    0.2553       157
#            2     0.4364    0.6076    0.5079       237
#            3     0.1594    0.0846    0.1106       130
#
#     accuracy                         0.3645       524
#    macro avg     0.2946    0.3072    0.2913       524
# weighted avg     0.3232    0.3645    0.3337       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-22-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.539344      0.539344         0.614836
# 1   RandomForest        0.969672      0.969672         0.970237
# 2       Adaboost        0.561475      0.561475         0.563576
# 3            GBM        0.924590      0.924590         0.930745
# 4            SVM        0.525410      0.525410         0.516534
# 5            KNN        0.548361      0.548361         0.540177
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.466560       0.425573     0.425573        0.320646       0.348863
# 1        0.969692       0.391221     0.391221        0.307093       0.318843
# 2        0.547397       0.398855     0.398855        0.361176       0.364829
# 3        0.924303       0.406489     0.406489        0.365096       0.365601
# 4        0.481714       0.404580     0.404580        0.349877       0.344175
# 5        0.525702       0.364504     0.364504        0.323204       0.333660

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3688    0.5180    0.4309       361
#            2     0.5714    0.4195    0.4838       553
#            3     0.3518    0.3529    0.3524       306
#
#     accuracy                         0.4320      1220
#    macro avg     0.4307    0.4302    0.4224      1220
# weighted avg     0.4564    0.4320    0.4352      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2524    0.3376    0.2888       157
#            2     0.3878    0.3207    0.3510       237
#            3     0.2119    0.1923    0.2016       130
#
#     accuracy                         0.2939       524
#    macro avg     0.2840    0.2835    0.2805       524
# weighted avg     0.3036    0.2939    0.2953       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-22-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.539344      0.539344         0.614836
# 1   RandomForest        0.969672      0.969672         0.970237
# 2       Adaboost        0.561475      0.561475         0.563576
# 3            GBM        0.924590      0.924590         0.930745
# 4            SVM        0.525410      0.525410         0.516534
# 5            KNN        0.548361      0.548361         0.540177
# 6            GNB        0.431967      0.431967         0.456392
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.466560       0.425573     0.425573        0.320646       0.348863
# 1        0.969692       0.391221     0.391221        0.307093       0.318843
# 2        0.547397       0.398855     0.398855        0.361176       0.364829
# 3        0.924303       0.406489     0.406489        0.365096       0.365601
# 4        0.481714       0.404580     0.404580        0.349877       0.344175
# 5        0.525702       0.364504     0.364504        0.323204       0.333660
# 6        0.435190       0.293893     0.293893        0.303558       0.295328
