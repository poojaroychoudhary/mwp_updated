# %% [markdown]
# Anova_w2v_100features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
import numpy as np 
import pandas as pd
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_W2v/data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                             Problem    Level      Type  \
# 0  There are constants    alpha  and    beta  suc...  Level 5  Algebra
# 1  The length of the segment between the points  ...  Level 5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...  Level 5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...  Level 5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...  Level 2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df.iloc[:,1].replace(['Level 1', 'Level 2', 'Level 3', 'Level 4', 'Level 5'],
                        [1, 2, 3, 4, 5], inplace=True)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       5  Algebra
# 1  The length of the segment between the points  ...       5  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       5  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       5  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       2  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
#define bins
bins = [0,2,4,5]
#name of the group 
group_names = ['Low', 'Moderate', 'High']
df['Level '] = pd.cut(df["Level "],bins,labels = group_names)

# %%
df.head(5)
# Out:
#                                             Problem  Level      Type  \
# 0  There are constants    alpha  and    beta  suc...   High  Algebra
# 1  The length of the segment between the points  ...   High  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...   High  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...   High  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...    Low  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
df['Level '] = df['Level '].map({'Low': 1, 'Moderate': 2, 'High': 3}).astype(int)

# %%
df.head()
# Out:
#                                             Problem   Level      Type  \
# 0  There are constants    alpha  and    beta  suc...       3  Algebra
# 1  The length of the segment between the points  ...       3  Algebra
# 2  Chewbacca has 20 pieces of cherry gum and 30 p...       3  Algebra
# 3  For some constants  a  and  b,  let   [f(x) = ...       3  Algebra
# 4  Calculate the sum  1 + 3 + 5 +   cdots + 15 + ...       1  Algebra
#
#                                             Solution  \
# 0  The numerator  x^2 - 80x + 1551  factors as  (...
# 1  By the distance formula, the distance from  (2...
# 2  If Chewbacca loses one pack of cherry gum, the...
# 3  Setting  x = 3,  we get  f(3) = -1.  Since  -1...
# 4  The arithmetic sequence 1, 3, 5,    dots , 17,...
#
#                                Extracted words(List)  \
# 0  ['There', 'are', 'constants', 'alpha', 'and', ...
# 1  ['The', 'length', 'of', 'the', 'segment', 'bet...
# 2  ['Chewbacca', 'has', 'pieces', 'of', 'cherry',...
# 3  ['For', 'some', 'constants', 'a', 'and', 'b', ...
# 4               ['Calculate', 'the', 'sum', 'cdots']
#
#                       Extracted Num(List)
# 0  ['2', '80', '1551', '2', '57', '2970']
# 1         ['2', '4', '4', '1', '2', '10']
# 2                       ['20', '30', '5']
# 3                    ['2', '8', '3', '2']
# 4             ['1', '3', '5', '15', '17']

# %%
import pandas as pd
path = "/content/drive/MyDrive/newpro/threeclass_problem/ANOVA_W2v/w2v_withstopwordchangelevels_100_features.csv"
x = pd.read_csv(path)
x.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.002116 -0.239260 -0.325717 -0.585718  1.039938  0.060327
# 1           1 -0.867871  0.003682  0.251795 -0.476409  0.330812 -0.491039
# 2           2 -0.717660 -0.152265 -0.233908 -0.201159  0.742183  0.219088
# 3           3  0.915288  0.319575 -0.415603  0.788572  0.558635  1.589368
# 4           4 -0.721817 -0.526454 -1.528320 -0.525874  0.346912  0.688800
#
#           6         7         8  ...        90        91        92        93  \
# 0  0.539150  0.063204 -1.146530  ... -0.557330 -0.213129  0.967595 -0.679170
# 1 -0.176860 -0.328605  1.772332  ...  0.450345 -1.719681  0.308228 -0.681609
# 2 -0.188894 -0.302008  0.994291  ...  0.609784 -1.492025 -0.495845 -0.492453
# 3 -0.034990 -1.244238 -0.593075  ...  0.335667  0.812611  0.148512 -0.076151
# 4  0.646072 -1.418958  1.275755  ... -0.153587 -0.894891 -1.084329 -0.043299
#
#          94        95        96        97        98        99
# 0  0.039355  0.110109  0.900935 -0.293670 -0.373394  0.011884
# 1  0.242334 -0.499605  0.208320 -0.021038  0.195223  0.521462
# 2  0.435485 -0.314890 -0.314912 -0.097566 -0.171710  0.934293
# 3 -1.306451  1.919921 -0.564158 -1.778560 -1.755762 -0.283051
# 4  0.506569 -0.498555 -2.205893  1.207277 -1.319166 -0.880797
#
# [5 rows x 101 columns]

# %%
x.drop(x.columns[[0]], axis=1, inplace=True)
x.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.002116 -0.239260 -0.325717 -0.585718  1.039938  0.060327  0.539150
# 1 -0.867871  0.003682  0.251795 -0.476409  0.330812 -0.491039 -0.176860
# 2 -0.717660 -0.152265 -0.233908 -0.201159  0.742183  0.219088 -0.188894
# 3  0.915288  0.319575 -0.415603  0.788572  0.558635  1.589368 -0.034990
# 4 -0.721817 -0.526454 -1.528320 -0.525874  0.346912  0.688800  0.646072
#
#           7         8         9  ...        90        91        92        93  \
# 0  0.063204 -1.146530 -0.439810  ... -0.557330 -0.213129  0.967595 -0.679170
# 1 -0.328605  1.772332 -1.161378  ...  0.450345 -1.719681  0.308228 -0.681609
# 2 -0.302008  0.994291  0.046773  ...  0.609784 -1.492025 -0.495845 -0.492453
# 3 -1.244238 -0.593075  2.953931  ...  0.335667  0.812611  0.148512 -0.076151
# 4 -1.418958  1.275755  1.919602  ... -0.153587 -0.894891 -1.084329 -0.043299
#
#          94        95        96        97        98        99
# 0  0.039355  0.110109  0.900935 -0.293670 -0.373394  0.011884
# 1  0.242334 -0.499605  0.208320 -0.021038  0.195223  0.521462
# 2  0.435485 -0.314890 -0.314912 -0.097566 -0.171710  0.934293
# 3 -1.306451  1.919921 -0.564158 -1.778560 -1.755762 -0.283051
# 4  0.506569 -0.498555 -2.205893  1.207277 -1.319166 -0.880797
#
# [5 rows x 100 columns]

# %%
y=df['Level ']

# %% [markdown]
# **Train Test Split**

# %%
# Train-Test-Split is performed

from sklearn.model_selection import train_test_split

# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((1220, 100), (524, 100))

# %%
print(y_train.value_counts(normalize=True)*100)
print("\n")
print(y_test.value_counts(normalize=True)*100)
# Out:
# 2    45.327869
# 1    29.590164
# 3    25.081967
# Name: Level , dtype: float64
#
#
# 2    45.229008
# 1    29.961832
# 3    24.809160
# Name: Level , dtype: float64

# %% [markdown]
# **Model Building**

# %%
def perceptron_classifier (X_train, y_train, X_test, y_test):
  p = Perceptron(random_state=150)
  p.fit(X_train, y_train)
  predictions_train = p.predict(X_train)
  predictions_test = p.predict(X_test)
  train_score = accuracy_score(predictions_train, y_train)
  #print("score on train data: ", train_score)
  test_score = f1_score(predictions_test, y_test, average='weighted' )
  print("Perceptron F1 score:", test_score)

# %%
from sklearn.linear_model import Perceptron
perceptron_classifier(X_train, y_train, X_test, y_test)
# Out:
# Perceptron F1 score: 0.36751139372883657

# %% [markdown]
# **Decision Tree**

# %%
clf_dt = DecisionTreeClassifier(max_depth=5, class_weight = "balanced")

# %%
clf_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', max_depth=5)

# %%
y_pred_train = clf_dt.predict(X_train)
y_pred_test = clf_dt.predict(X_test)

# %%
def classifcation_report_train_test(y_train, y_train_pred, y_test, y_test_pred):

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TRAIN DATA
            =========================================
            ''')
    print(classification_report(y_train, y_train_pred, digits=4))

    print('''
            =========================================
               CLASSIFICATION REPORT FOR TEST DATA
            =========================================
            ''')
    print(classification_report(y_test, y_test_pred, digits=4))

# %%
scores = pd.DataFrame(columns=['Model', 'Train_Accuracy', 'Train_Recall', 'Train_Precision', 'Train_F1_Score', 
                               'Test_Accuracy', 'Test_Recall', 'Test_Precision', 'Test_F1_Score'])

def get_metrics(train_actual, train_predicted, test_actual, test_predicted, model_description, dataframe):

    train_accuracy  = accuracy_score(train_actual, train_predicted)
    train_recall    = recall_score(train_actual, train_predicted, average="weighted")
    train_precision = precision_score(train_actual, train_predicted, average="weighted")
    train_f1score   = f1_score(train_actual, train_predicted, average="weighted")
    
    test_accuracy   = accuracy_score(test_actual, test_predicted)
    test_recall     = recall_score(test_actual, test_predicted, average="weighted")
    test_precision  = precision_score(test_actual, test_predicted, average="weighted")
    test_f1score    = f1_score(test_actual, test_predicted, average="weighted")

    dataframe       = dataframe.append(pd.Series([model_description, 
                                                  train_accuracy, train_recall, train_precision, train_f1score,
                                                  test_accuracy, test_recall, test_precision, test_f1score],
                                                 index=scores.columns ), 
                                       ignore_index=True)

    return(dataframe)

# %%
scores = get_metrics(y_train, y_pred_train, y_test, y_pred_test, "DecisionTrees", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.335246      0.335246         0.674638
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.260488       0.265267     0.265267        0.385203       0.172992

# %% [markdown]
# **Random Forest**

# %%
clf_rf = RandomForestClassifier(class_weight = "balanced")

# %%
clf_rf.fit(X=X_train, y=y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred_train1 = clf_rf.predict(X_train)
y_pred_test1 = clf_rf.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train1, y_test, y_pred_test1)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9972    0.9972    0.9972       361
#            2     0.9964    0.9982    0.9973       553
#            3     1.0000    0.9967    0.9984       306
#
#     accuracy                         0.9975      1220
#    macro avg     0.9979    0.9974    0.9976      1220
# weighted avg     0.9975    0.9975    0.9975      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2258    0.1338    0.1680       157
#            2     0.4370    0.7468    0.5514       237
#            3     0.2308    0.0462    0.0769       130
#
#     accuracy                         0.3893       524
#    macro avg     0.2979    0.3089    0.2654       524
# weighted avg     0.3226    0.3893    0.3188       524

# %%
scores = get_metrics(y_train, y_pred_train1, y_test, y_pred_test1, "RandomForest", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.335246      0.335246         0.674638
# 1   RandomForest        0.997541      0.997541         0.997544
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.260488       0.265267     0.265267        0.385203       0.172992
# 1        0.997541       0.389313     0.389313        0.322575       0.318813

# %% [markdown]
# **AdaBoost**

# %%
clf_adaboost =  AdaBoostClassifier()

# %%
clf_adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred_train2 = clf_adaboost.predict(X_train)
y_pred_test2 = clf_adaboost.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train2, y_test, y_pred_test2)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.6181    0.3407    0.4393       361
#            2     0.5270    0.8481    0.6500       553
#            3     0.6107    0.2614    0.3661       306
#
#     accuracy                         0.5508      1220
#    macro avg     0.5852    0.4834    0.4852      1220
# weighted avg     0.5749    0.5508    0.5165      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2474    0.1529    0.1890       157
#            2     0.4338    0.6498    0.5203       237
#            3     0.2361    0.1308    0.1683       130
#
#     accuracy                         0.3721       524
#    macro avg     0.3058    0.3111    0.2925       524
# weighted avg     0.3289    0.3721    0.3337       524

# %%
scores = get_metrics(y_train, y_pred_train2, y_test, y_pred_test2, "Adaboost", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.504918      0.504918         0.719461
# 1   RandomForest        0.997541      0.997541         0.997554
# 2       Adaboost        0.550820      0.550820         0.574929
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.391578       0.438931     0.438931        0.328983       0.304142
# 1        0.997541       0.381679     0.381679        0.305855       0.313634
# 2        0.516466       0.372137     0.372137        0.328914       0.333692

# %% [markdown]
# **Gradient Boosting Classifier**

# %%
clf_gbm = GradientBoostingClassifier()

# %%
clf_gbm.fit(X=X_train, y=y_train)
# Out:
# GradientBoostingClassifier()

# %%
y_pred_train3 = clf_gbm.predict(X_train)
y_pred_test3 = clf_gbm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train3, y_test, y_pred_test3)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.9693    0.8753    0.9199       361
#            2     0.8693    0.9982    0.9293       553
#            3     0.9923    0.8399    0.9097       306
#
#     accuracy                         0.9221      1220
#    macro avg     0.9436    0.9045    0.9197      1220
# weighted avg     0.9297    0.9221    0.9216      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2549    0.1656    0.2008       157
#            2     0.4373    0.6624    0.5268       237
#            3     0.1905    0.0923    0.1244       130
#
#     accuracy                         0.3721       524
#    macro avg     0.2942    0.3068    0.2840       524
# weighted avg     0.3214    0.3721    0.3293       524

# %%
scores = get_metrics(y_train, y_pred_train3, y_test, y_pred_test3, "GBM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.504918      0.504918         0.719461
# 1   RandomForest        0.997541      0.997541         0.997554
# 2       Adaboost        0.550820      0.550820         0.574929
# 3            GBM        0.922131      0.922131         0.929739
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.391578       0.438931     0.438931        0.328983       0.304142
# 1        0.997541       0.381679     0.381679        0.305855       0.313634
# 2        0.516466       0.372137     0.372137        0.328914       0.333692
# 3        0.921620       0.372137     0.372137        0.321427       0.329293

# %% [markdown]
# **SVM Model**

# %%
linear_svm = SVC(kernel='linear', C=1, class_weight = "balanced")

# %%
linear_svm.fit(X=X_train, y= y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
y_pred_train4 = linear_svm.predict(X_train)
y_pred_test4 = linear_svm.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train4, y_test, y_pred_test4)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3585    0.4875    0.4131       361
#            2     0.5531    0.3580    0.4347       553
#            3     0.3315    0.4020    0.3634       306
#
#     accuracy                         0.4074      1220
#    macro avg     0.4144    0.4158    0.4037      1220
# weighted avg     0.4399    0.4074    0.4104      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2441    0.3312    0.2811       157
#            2     0.4207    0.2574    0.3194       237
#            3     0.2410    0.3077    0.2703       130
#
#     accuracy                         0.2920       524
#    macro avg     0.3019    0.2988    0.2902       524
# weighted avg     0.3232    0.2920    0.2957       524

# %%
scores = get_metrics(y_train, y_pred_train4, y_test, y_pred_test4, "SVM", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.335246      0.335246         0.674638
# 1   RandomForest        0.997541      0.997541         0.997544
# 2            SVM        0.407377      0.407377         0.439918
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.260488       0.265267     0.265267        0.385203       0.172992
# 1        0.997541       0.389313     0.389313        0.322575       0.318813
# 2        0.410425       0.291985     0.291985        0.323201       0.295717

# %% [markdown]
# **KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X=X_train, y=y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train5 = knn.predict(X_train)
y_pred_test5 = knn.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train5, y_test, y_pred_test5)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.5029    0.4875    0.4951       361
#            2     0.5627    0.7143    0.6295       553
#            3     0.4643    0.2549    0.3291       306
#
#     accuracy                         0.5320      1220
#    macro avg     0.5099    0.4856    0.4846      1220
# weighted avg     0.5203    0.5320    0.5144      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.2788    0.2930    0.2857       157
#            2     0.4476    0.5401    0.4895       237
#            3     0.2603    0.1462    0.1872       130
#
#     accuracy                         0.3683       524
#    macro avg     0.3289    0.3264    0.3208       524
# weighted avg     0.3505    0.3683    0.3534       524

# %%
scores = get_metrics(y_train, y_pred_train5, y_test, y_pred_test5, "KNN", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.504918      0.504918         0.719461
# 1   RandomForest        0.997541      0.997541         0.997554
# 2       Adaboost        0.550820      0.550820         0.574929
# 3            GBM        0.922131      0.922131         0.929739
# 4            SVM        0.456557      0.456557         0.337301
# 5            KNN        0.531967      0.531967         0.520298
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.391578       0.438931     0.438931        0.328983       0.304142
# 1        0.997541       0.381679     0.381679        0.305855       0.313634
# 2        0.516466       0.372137     0.372137        0.328914       0.333692
# 3        0.921620       0.372137     0.372137        0.321427       0.329293
# 4        0.300034       0.438931     0.438931        0.201994       0.276667
# 5        0.514373       0.368321     0.368321        0.350525       0.353435

# %% [markdown]
# **GNB**

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

# %%
nb.fit(X=X_train, y=y_train)
# Out:
# GaussianNB()

# %%
y_pred_train6 = nb.predict(X_train)
y_pred_test6 = nb.predict(X_test)

# %%
classifcation_report_train_test(y_train, y_pred_train6, y_test, y_pred_test6)
# Out:
#             =========================================
#                CLASSIFICATION REPORT FOR TRAIN DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.3333    0.0582    0.0991       361
#            2     0.4661    0.1989    0.2788       553
#            3     0.2519    0.7582    0.3782       306
#
#     accuracy                         0.2975      1220
#    macro avg     0.3504    0.3384    0.2520      1220
# weighted avg     0.3731    0.2975    0.2505      1220
#
#
#             =========================================
#                CLASSIFICATION REPORT FOR TEST DATA
#             =========================================
#
#               precision    recall  f1-score   support
#
#            1     0.1905    0.0255    0.0449       157
#            2     0.4722    0.2152    0.2957       237
#            3     0.2430    0.7385    0.3657       130
#
#     accuracy                         0.2882       524
#    macro avg     0.3019    0.3264    0.2354       524
# weighted avg     0.3309    0.2882    0.2379       524

# %%
scores = get_metrics(y_train, y_pred_train6, y_test, y_pred_test6, "GNB", scores)
scores
# Out:
# <ipython-input-21-3ef4ce65b0ea>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe       = dataframe.append(pd.Series([model_description,
#            Model  Train_Accuracy  Train_Recall  Train_Precision  \
# 0  DecisionTrees        0.504918      0.504918         0.719461
# 1   RandomForest        0.997541      0.997541         0.997554
# 2       Adaboost        0.550820      0.550820         0.574929
# 3            GBM        0.922131      0.922131         0.929739
# 4            SVM        0.456557      0.456557         0.337301
# 5            KNN        0.531967      0.531967         0.520298
# 6            GNB        0.297541      0.297541         0.373089
#
#    Train_F1_Score  Test_Accuracy  Test_Recall  Test_Precision  Test_F1_Score
# 0        0.391578       0.438931     0.438931        0.328983       0.304142
# 1        0.997541       0.381679     0.381679        0.305855       0.313634
# 2        0.516466       0.372137     0.372137        0.328914       0.333692
# 3        0.921620       0.372137     0.372137        0.321427       0.329293
# 4        0.300034       0.438931     0.438931        0.201994       0.276667
# 5        0.514373       0.368321     0.368321        0.350525       0.353435
# 6        0.250550       0.288168     0.288168        0.330947       0.237917
